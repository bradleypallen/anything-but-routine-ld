# %%
import rdflib, glob, mimeparse, requests
from rdflib import URIRef, Literal
from rdflib.namespace import RDF, RDFS, DCTERMS, SKOS

# %%
abrc = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/classification/")
abri = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/instance/")
abrw = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/work/")
bf = rdflib.Namespace("http://id.loc.gov/ontologies/bibframe/")
arm = rdflib.Namespace("https://w3id.org/arm/core/ontology/0.1/")

# %%
def initialize_abr_graph():
    g = rdflib.Graph()
    g.bind("abrc", "https://wsburroughs.link/anything-but-routine/4.0/classification/")
    g.bind("abri", "https://wsburroughs.link/anything-but-routine/4.0/instance/")
    g.bind("abrw", "https://wsburroughs.link/anything-but-routine/4.0/work/")
    g.bind("bf", "http://id.loc.gov/ontologies/bibframe/")
    g.bind("arm", "https://w3id.org/arm/core/ontology/0.1/")
    return g

# %%
headers = { 'Accept': 'text/turtle, application/rdf+xml' }

res = requests.get(abri['A8c'], headers=headers)

# %%
res.status_code  == requests.codes.ok
# Out:
# True

# %%
def find_and_follow(uri, level=3):
    if not uri in graph.subjects():
        res = requests.get(uri, headers=headers)
        print(f'{res.status_code} {res.reason}: {uri}')
        if res.status_code  == requests.codes.ok:
            content_type = res.headers.get('content-type')
            (media_type, media_subtype, params) = mimeparse.parse_mime_type(content_type)
            format = f'{media_type}/{media_subtype}'
            print(f'Parsing {format}')
            n_triples = len(graph)
            graph.parse(data=res.text, format=format)
            print(f'Added {len(graph)-n_triples} triples')
            if level > 0:
                for o in graph.objects(uri, None):
                    if type(o) == rdflib.term.URIRef:
                        find_and_follow(o, level=level-1)

# %%
graph = initialize_abr_graph()
find_and_follow(abrw['A8'])
# Out:
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/work/A8
# Parsing text/turtle
# Added 26 triples
# 200 OK: http://id.loc.gov/ontologies/bibframe/Text
# Parsing application/rdf+xml
# Added 5 triples
# 200 OK: http://www.w3.org/2002/07/owl#Class
# Parsing text/turtle
# Added 450 triples
# 200 OK: http://www.w3.org/2000/01/rdf-schema#Class
# Parsing text/turtle
# Added 87 triples
# 200 OK: http://www.w3.org/2002/07/owl#
# Parsing text/turtle
# Added 0 triples
# 200 OK: http://id.loc.gov/ontologies/bibframe/Work
# Parsing application/rdf+xml
# Added 140 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/classification/A
# Parsing text/turtle
# Added 4 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/classification/Schottlaender_v4_0
# Parsing text/turtle
# Added 3 triples
# 200 OK: http://id.loc.gov/ontologies/bibframe/Classification
# Parsing application/rdf+xml
# Added 46 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/instance/A8e
# Parsing text/turtle
# Added 51 triples
# 200 OK: http://id.loc.gov/ontologies/bibframe/Instance
# Parsing application/rdf+xml
# Added 213 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/instance/A8c
# Parsing text/turtle
# Added 39 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/instance/A8d
# Parsing text/turtle
# Added 40 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/instance/A8a
# Parsing text/turtle
# Added 49 triples
# 200 OK: https://wsburroughs.link/anything-but-routine/4.0/instance/A8b
# Parsing text/turtle
# Added 40 triples

# %%
len(graph)
# Out:
# 1193

# %%
not abrw['A8'] in graph.subjects()
# Out:
# True

# %%
for (s, p, o) in graph.triples( (None, None, None) ):
    print(f'{s} {p} {o} .')
# Out:
# ub106bL28C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Note .
# http://www.w3.org/2002/07/owl#sameAs http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Thing .
# http://www.w3.org/2002/07/owl#maxCardinality http://www.w3.org/2000/01/rdf-schema#label maxCardinality .
# http://id.loc.gov/ontologies/bibframe/editionStatement http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://id.loc.gov/ontologies/bibframe/layout http://www.w3.org/2000/01/rdf-schema#label Layout .
# http://id.loc.gov/ontologies/bibframe/version http://www.w3.org/2000/01/rdf-schema#label Version .
# http://id.loc.gov/ontologies/bibframe/spanEnd http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#ReflexiveProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/eventContentOf http://www.w3.org/2004/02/skos/core#definition Event that is the content of the described work. .
# http://www.w3.org/2002/07/owl#Class http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/subseriesStatement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/itemPortion http://purl.org/dc/terms/modified 2016-04-21 (New) .
# ub97bL13C20 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Agent .
# http://id.loc.gov/ontologies/bibframe/classificationPortion http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Classification .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://purl.org/dc/terms/modified 2016-04-29 (added inverse) .
# http://id.loc.gov/ontologies/bibframe/classificationPortion http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#topDataProperty http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Thing .
# http://www.w3.org/2002/07/owl#oneOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://id.loc.gov/ontologies/bibframe/reductionRatio http://www.w3.org/2000/01/rdf-schema#label Reduction ratio .
# http://id.loc.gov/ontologies/bibframe/fontSize http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#OntologyProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/dimensions http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/2000/01/rdf-schema#label differentFrom .
# http://id.loc.gov/ontologies/bibframe/historyOfWork http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/temporalCoverage http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/contributor ub97bL13C20 .
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#label label .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/identifiedBy ub106bL17C21 .
# http://id.loc.gov/ontologies/bibframe/temporalCoverage http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/projectionCharacteristic http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#targetValue http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/responsibilityStatement http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://www.w3.org/2000/01/rdf-schema#label Expressed as .
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Resource .
# ub97bL32C26 http://id.loc.gov/ontologies/bibframe/date 1957 .
# http://www.w3.org/2002/07/owl#versionInfo http://www.w3.org/2000/01/rdf-schema#comment The annotation property that provides version information for an ontology or another OWL construct. .
# http://www.w3.org/2002/07/owl#disjointWith http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/itemPortion http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Classification .
# http://id.loc.gov/ontologies/bibframe/musicThematicNumber http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2002/07/owl#unionOf http://www.w3.org/2000/01/rdf-schema#label unionOf .
# http://www.w3.org/2002/07/owl#imports http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/seriesStatement http://www.w3.org/2000/01/rdf-schema#label Series statement .
# http://www.w3.org/2002/07/owl#AllDisjointClasses http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/extent http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/note ub106bL30C9 .
# http://id.loc.gov/ontologies/bibframe/expressionOf http://www.w3.org/2004/02/skos/core#definition Work that the described Work is an expression of. For use to connect Works under FRBR/RDA rules. .
# http://id.loc.gov/ontologies/bibframe/editionStatement http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#DataRange http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://www.w3.org/2002/07/owl#topObjectProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2000/01/rdf-schema#Literal http://www.w3.org/2000/01/rdf-schema#label Literal .
# http://www.w3.org/2002/07/owl#incompatibleWith http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#bottomDataProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/musicMedium http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/voice http://www.w3.org/2000/01/rdf-schema#label Voice .
# http://www.w3.org/2000/01/rdf-schema#Resource http://www.w3.org/2000/01/rdf-schema#comment The class resource, everything. .
# http://id.loc.gov/ontologies/bibframe/musicOpusNumber http://www.w3.org/2000/01/rdf-schema#label Music opus number .
# http://id.loc.gov/ontologies/bibframe/mount http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/reproductionOf http://purl.org/dc/terms/modified 2016-04-29 (added inverse) .
# http://id.loc.gov/ontologies/bibframe/fontSize http://www.w3.org/2000/01/rdf-schema#label Font size .
# http://id.loc.gov/ontologies/bibframe/reproductionOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#AllDisjointClasses http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#onProperties http://www.w3.org/2000/01/rdf-schema#label onProperties .
# http://www.w3.org/2002/07/owl#SymmetricProperty http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#intersectionOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/Instance http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class .
# http://id.loc.gov/ontologies/bibframe/voice http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/instrument http://www.w3.org/2000/01/rdf-schema#label Instrument .
# http://id.loc.gov/ontologies/bibframe/provisionActivityStatement http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#comment The subject is a subclass of a class. .
# http://www.w3.org/2002/07/owl#AllDisjointProperties http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/productionMethod http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/ProductionMethod .
# ub97bL20C9 http://id.loc.gov/ontologies/bibframe/source Schottlaender v4.0 .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://www.w3.org/2000/01/rdf-schema#label Reproduced as .
# http://id.loc.gov/ontologies/bibframe/musicThematicNumber http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#annotatedSource http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/originPlace http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/place .
# http://www.w3.org/2002/07/owl#AsymmetricProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#DeprecatedClass http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/classificationPortion http://www.w3.org/2000/01/rdf-schema#label Classification number .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://purl.org/dc/terms/modified 2016-04-29 (added inverse) .
# http://www.w3.org/2002/07/owl#withRestrictions http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#AllDifferent http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Resource .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/2000/01/rdf-schema#label equivalentProperty .
# http://id.loc.gov/ontologies/bibframe/soundCharacteristic http://www.w3.org/2004/02/skos/core#definition Technical specification relating to the encoding of sound in a resource. .
# http://www.w3.org/2002/07/owl#backwardCompatibleWith http://www.w3.org/2000/01/rdf-schema#label backwardCompatibleWith .
# http://www.w3.org/2002/07/owl#ReflexiveProperty http://www.w3.org/2000/01/rdf-schema#label ReflexiveProperty .
# http://id.loc.gov/ontologies/bibframe/temporalCoverage http://www.w3.org/2000/01/rdf-schema#label Temporal coverage .
# http://www.w3.org/2002/07/owl#topDataProperty http://www.w3.org/2000/01/rdf-schema#comment The data property that relates every individual to every data value. .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#label equivalentClass .
# http://id.loc.gov/ontologies/bibframe/originDate http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2002/07/owl#Annotation http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/fontSize http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#annotatedProperty http://www.w3.org/2000/01/rdf-schema#comment The property that determines the predicate of an annotated axiom or annotated annotation. .
# http://id.loc.gov/ontologies/bibframe/reductionRatio http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#annotatedTarget http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Resource .
# http://www.w3.org/2002/07/owl#Thing http://www.w3.org/2000/01/rdf-schema#label Thing .
# http://id.loc.gov/ontologies/bibframe/originPlace http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/Place .
# http://id.loc.gov/ontologies/bibframe/bookFormat http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/BookFormat .
# http://www.w3.org/2000/01/rdf-schema#member http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://www.w3.org/2002/07/owl#sourceIndividual http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#DeprecatedClass http://www.w3.org/2000/01/rdf-schema#comment The class of deprecated classes. .
# http://id.loc.gov/ontologies/bibframe/geographicCoverage http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/GeographicCoverage .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://id.loc.gov/ontologies/bibframe/expressionOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/hasInstance http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/seriesEnumeration http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2000/01/rdf-schema#comment http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://www.w3.org/2002/07/owl#topDataProperty http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2002/07/owl#DeprecatedClass http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#minCardinality http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#versionIRI http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Ontology .
# http://www.w3.org/2002/07/owl#targetIndividual http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/emulsion http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/emulsion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#topObjectProperty http://www.w3.org/2000/01/rdf-schema#label topObjectProperty .
# http://www.w3.org/2002/07/owl#AllDifferent http://www.w3.org/2000/01/rdf-schema#label AllDifferent .
# http://id.loc.gov/ontologies/bibframe/editionEnumeration http://www.w3.org/2004/02/skos/core#definition Enumeration of the edition; usually transcribed. .
# http://www.w3.org/2002/07/owl#sourceIndividual http://www.w3.org/2000/01/rdf-schema#label sourceIndividual .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/2000/01/rdf-schema#comment The property that determines that two given properties are equivalent. .
# http://id.loc.gov/ontologies/bibframe/originDate http://www.w3.org/2000/01/rdf-schema#label Associated title date .
# http://www.w3.org/2002/07/owl#backwardCompatibleWith http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/tableSeq http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Classification .
# http://www.w3.org/2002/07/owl#propertyDisjointWith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/hasEquivalent .
# http://www.w3.org/2002/07/owl#someValuesFrom http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#OntologyProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/musicSerialNumber http://www.w3.org/2004/02/skos/core#definition Numeric designation for musical works consecutively numbered in music reference sources. .
# http://www.w3.org/2002/07/owl#annotatedTarget http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/responsibilityStatement http://www.w3.org/2004/02/skos/core#definition Statement relating to any persons, families, or corporate bodies responsible for the creation of, or contributing to the content of a resource; usually transcribed. .
# http://id.loc.gov/ontologies/bibframe/baseMaterial http://www.w3.org/2004/02/skos/core#definition Underlying physical material of a resource. .
# http://www.w3.org/2002/07/owl#onDatatype http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://id.loc.gov/ontologies/bibframe/hasInstance http://www.w3.org/2000/01/rdf-schema#label Instance of Work .
# http://www.w3.org/2002/07/owl#unionOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://id.loc.gov/ontologies/bibframe/historyOfWork http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2002/07/owl#hasKey http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/generation http://www.w3.org/2000/01/rdf-schema#label Generation .
# http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/digitalCharacteristic http://www.w3.org/2004/02/skos/core#definition Technical specification relating to the digital encoding of text, image, audio, video, and other types of data in a resource. .
# http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/Work http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class .
# http://www.w3.org/2002/07/owl#DataRange http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#Literal http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/editionEnumeration http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#hasSelf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Restriction .
# http://www.w3.org/2002/07/owl#Axiom http://www.w3.org/2000/01/rdf-schema#label Axiom .
# http://www.w3.org/2000/01/rdf-schema#Class http://www.w3.org/2000/01/rdf-schema#label Class .
# http://www.w3.org/2002/07/owl#ObjectProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#complementOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#hasValue http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# ub106bL13C20 http://www.w3.org/2000/01/rdf-schema#label William S. Burroughs .
# http://www.w3.org/2002/07/owl#AsymmetricProperty http://www.w3.org/2000/01/rdf-schema#comment The class of asymmetric properties. .
# http://id.loc.gov/ontologies/bibframe/reductionRatio http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/ReductionRatio .
# http://id.loc.gov/ontologies/bibframe/voice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#Restriction http://www.w3.org/2000/01/rdf-schema#comment The class of property restrictions. .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/edition http://www.w3.org/2000/01/rdf-schema#label Classification scheme edition .
# http://www.w3.org/2002/07/owl#annotatedSource http://www.w3.org/2000/01/rdf-schema#label annotatedSource .
# http://www.w3.org/2002/07/owl#priorVersion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#OntologyProperty .
# http://www.w3.org/2002/07/owl#members http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#comment The subject is a subproperty of a property. .
# http://id.loc.gov/ontologies/bibframe/musicKey http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/reproductionOf http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/geographicCoverage http://purl.org/dc/terms/modified 2017-02-06 (Changed from data to object property) .
# http://www.w3.org/2002/07/owl#bottomDataProperty http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Thing .
# http://id.loc.gov/ontologies/bibframe/provisionActivityStatement http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2002/07/owl#topObjectProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/instanceOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/relatedTo .
# http://id.loc.gov/ontologies/bibframe/soundCharacteristic http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/note ub106bL28C9 .
# https://wsburroughs.link/anything-but-routine/4.0/work/C3 http://id.loc.gov/ontologies/bibframe/classification https://wsburroughs.link/anything-but-routine/4.0/classification/C .
# http://www.w3.org/2002/07/owl#disjointWith http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Class .
# http://id.loc.gov/ontologies/bibframe/originPlace http://www.w3.org/2000/01/rdf-schema#label Associated title place .
# http://id.loc.gov/ontologies/bibframe/legalDate http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/date .
# http://id.loc.gov/ontologies/bibframe/Text http://www.w3.org/2000/01/rdf-schema#subClassOf http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/musicThematicNumber http://www.w3.org/2000/01/rdf-schema#label Music thematic number .
# http://www.w3.org/2002/07/owl#Class http://www.w3.org/2000/01/rdf-schema#comment The class of OWL classes. .
# http://www.w3.org/2002/07/owl#maxCardinality http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# ub105bL14C20 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Agent .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/schedulePart http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/2000/01/rdf-schema#comment Further information about the subject resource. .
# http://www.w3.org/2002/07/owl#someValuesFrom http://www.w3.org/2000/01/rdf-schema#label someValuesFrom .
# http://www.w3.org/2002/07/owl#datatypeComplementOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://id.loc.gov/ontologies/bibframe/Work http://www.w3.org/2000/01/rdf-schema#label Work .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/note ub97bL30C9 .
# http://www.w3.org/2002/07/owl#sameAs http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Thing .
# http://www.w3.org/2002/07/owl#cardinality http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#nonNegativeInteger .
# ub106bL20C9 http://id.loc.gov/ontologies/bibframe/source Schottlaender v4.0 .
# http://www.w3.org/2002/07/owl#withRestrictions http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://id.loc.gov/ontologies/bibframe/schedulePart http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#assertionProperty http://www.w3.org/2000/01/rdf-schema#label assertionProperty .
# http://id.loc.gov/ontologies/bibframe/geographicCoverage http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#members http://www.w3.org/2000/01/rdf-schema#comment The property that determines the collection of members in either a owl:AllDifferent, owl:AllDisjointClasses or owl:AllDisjointProperties axiom. .
# http://id.loc.gov/ontologies/bibframe/systemRequirement http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#priorVersion http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#intersectionOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# ub97bL13C20 http://id.loc.gov/ontologies/bibframe/role author .
# http://www.w3.org/2002/07/owl#onProperty http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#Annotation http://www.w3.org/2000/01/rdf-schema#comment The class of annotated annotations for which the RDF serialization consists of an annotated subject, predicate and object. .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#assertionProperty http://www.w3.org/2000/01/rdf-schema#comment The property that determines the predicate of a negative property assertion. .
# http://www.w3.org/2002/07/owl#someValuesFrom http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#FunctionalProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#bottomObjectProperty http://www.w3.org/2000/01/rdf-schema#label bottomObjectProperty .
# ub106bL17C21 http://id.loc.gov/ontologies/bibframe/source Maynard & Miles .
# http://www.w3.org/2000/01/rdf-schema#Datatype http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://id.loc.gov/ontologies/bibframe/instrument http://www.w3.org/2004/02/skos/core#definition Instrument for which a musical Work is appropriate. .
# http://www.w3.org/2002/07/owl#NegativePropertyAssertion http://www.w3.org/2000/01/rdf-schema#comment The class of negative property assertions. .
# http://id.loc.gov/ontologies/bibframe/extent http://www.w3.org/2000/01/rdf-schema#label Extent .
# http://www.w3.org/2002/07/owl#InverseFunctionalProperty http://www.w3.org/2000/01/rdf-schema#label InverseFunctionalProperty .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#comment The property that determines that two given classes are equivalent, and that is used to specify datatype definitions. .
# http://www.w3.org/2002/07/owl#intersectionOf http://www.w3.org/2000/01/rdf-schema#label intersectionOf .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/relatedTo .
# http://id.loc.gov/ontologies/bibframe/content http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2000/01/rdf-schema#Class http://www.w3.org/2000/01/rdf-schema#comment The class of classes. .
# http://id.loc.gov/ontologies/bibframe/expressionOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/relatedTo .
# https://wsburroughs.link/anything-but-routine/4.0/classification/Schottlaender_v4_0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Classification .
# http://id.loc.gov/ontologies/bibframe/systemRequirement http://www.w3.org/2000/01/rdf-schema#label Equipment or system requirements .
# http://id.loc.gov/ontologies/bibframe/musicThematicNumber http://www.w3.org/2004/02/skos/core#definition Numeric designation for a musical work as found in a thematic index for the composer. .
# http://id.loc.gov/ontologies/bibframe/hasItem http://purl.org/dc/terms/modified 2016-04-29 (added inverse) .
# http://id.loc.gov/ontologies/bibframe/dimensions http://www.w3.org/2004/02/skos/core#definition Measurements of the carrier or carriers and/or the container of a resource. .
# http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://id.loc.gov/ontologies/bibframe/systemRequirement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/provisionActivity http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/seriesEnumeration http://purl.org/dc/terms/modified 2016-04-21 (New) .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/instanceOf https://wsburroughs.link/anything-but-routine/4.0/work/C3 .
# http://www.w3.org/2002/07/owl#maxQualifiedCardinality http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#nonNegativeInteger .
# http://www.w3.org/2002/07/owl#NamedIndividual http://www.w3.org/2000/01/rdf-schema#label NamedIndividual .
# ub106bL32C26 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/ProvisionActivity .
# http://www.w3.org/2002/07/owl#hasValue http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/reductionRatio http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://www.w3.org/2002/07/owl#inverseOf http://id.loc.gov/ontologies/bibframe/expressionOf .
# http://www.w3.org/2002/07/owl http://www.w3.org/2002/07/owl#imports http://www.w3.org/2000/01/rdf-schema .
# http://www.w3.org/2002/07/owl#targetValue http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#NegativePropertyAssertion .
# http://id.loc.gov/ontologies/bibframe/originPlace http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# https://wsburroughs.link/anything-but-routine/4.0/classification/Schottlaender_v4_0 http://www.w3.org/2000/01/rdf-schema#label Schottlaender v4.0 .
# http://www.w3.org/2002/07/owl#assertionProperty http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#distinctMembers http://www.w3.org/2000/01/rdf-schema#label distinctMembers .
# http://id.loc.gov/ontologies/bibframe/originPlace http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://www.w3.org/2002/07/owl#sourceIndividual http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#NegativePropertyAssertion .
# http://www.w3.org/2002/07/owl#annotatedTarget http://www.w3.org/2000/01/rdf-schema#comment The property that determines the object of an annotated axiom or annotated annotation. .
# http://www.w3.org/2002/07/owl#disjointWith http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Class .
# http://www.w3.org/2000/01/rdf-schema#Container http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# ub106bL32C26 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Publication .
# ub107bL14C20 http://www.w3.org/2000/01/rdf-schema#label William S. Burroughs .
# http://id.loc.gov/ontologies/bibframe/content http://www.w3.org/2004/02/skos/core#definition Categorization reflecting the fundamental form of communication in which the content is expressed and the human sense through which it is intended to be perceived. .
# ub106bL17C21 http://www.w3.org/1999/02/22-rdf-syntax-ns#value C1 .
# http://www.w3.org/2000/01/rdf-schema#Datatype http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl http://www.w3.org/2002/07/owl#versionIRI http://www.w3.org/2002/07/owl .
# http://id.loc.gov/ontologies/bibframe/musicThematicNumber http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2000/01/rdf-schema#member http://www.w3.org/2000/01/rdf-schema#label member .
# http://www.w3.org/2002/07/owl#assertionProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/provisionActivityStatement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/soundCharacteristic http://purl.org/dc/terms/modified 2016-04-21 (fixed name and range typos) .
# http://id.loc.gov/ontologies/bibframe/reproductionOf http://www.w3.org/2002/07/owl#inverseOf http://id.loc.gov/ontologies/bibframe/hasReproduction .
# http://www.w3.org/2002/07/owl#datatypeComplementOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Datatype .
# ub105bL14C20 http://id.loc.gov/ontologies/bibframe/role author .
# http://www.w3.org/2002/07/owl#incompatibleWith http://www.w3.org/2000/01/rdf-schema#comment The annotation property that indicates that a given ontology is incompatible with another ontology. .
# http://www.w3.org/2002/07/owl#oneOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/musicSerialNumber http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/Classification http://www.w3.org/2004/02/skos/core#definition System of coding and organizing materials according to their subject. .
# http://www.w3.org/2002/07/owl#minQualifiedCardinality http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Restriction .
# http://id.loc.gov/ontologies/bibframe/musicMedium http://www.w3.org/2000/01/rdf-schema#label Music medium of performance .
# http://www.w3.org/2002/07/owl#allValuesFrom http://www.w3.org/2000/01/rdf-schema#comment The property that determines the class that a universal property restriction refers to. .
# https://wsburroughs.link/anything-but-routine/4.0/classification/C http://www.w3.org/2000/01/rdf-schema#subClassOf https://wsburroughs.link/anything-but-routine/4.0/classification/Schottlaender_v4_0 .
# http://www.w3.org/2002/07/owl#onDatatype http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://www.w3.org/2002/07/owl#backwardCompatibleWith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#OntologyProperty .
# http://id.loc.gov/ontologies/bibframe/schedulePart http://www.w3.org/2004/02/skos/core#definition Designates whether the classification number is from the standard or optional part of a schedule or table. .
# http://id.loc.gov/ontologies/bibframe/instrument http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/mount http://www.w3.org/2004/02/skos/core#definition Physical material used for the support or backing to which the base material of a resource has been attached. .
# http://www.w3.org/2002/07/owl#intersectionOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/dimensions http://www.w3.org/2000/01/rdf-schema#label Dimensions .
# http://www.w3.org/2002/07/owl#backwardCompatibleWith http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Ontology .
# http://www.w3.org/2000/01/rdf-schema#Resource http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://www.w3.org/2000/01/rdf-schema# http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/2000/01/rdf-schema-more .
# http://id.loc.gov/ontologies/bibframe/layout http://purl.org/dc/terms/modified 2016-04-21 (New) .
# ub106bL28C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#value Letter dated “August 3rd, 1956.” .
# http://id.loc.gov/ontologies/bibframe/subseriesStatement http://www.w3.org/2004/02/skos/core#definition Statement of the subseries the resource is in; usually transcribed; includes the ISSN if applicable. .
# http://www.w3.org/2002/07/owl#sameAs http://www.w3.org/2000/01/rdf-schema#label sameAs .
# http://www.w3.org/2002/07/owl#targetIndividual http://www.w3.org/2000/01/rdf-schema#label targetIndividual .
# http://www.w3.org/2002/07/owl#IrreflexiveProperty http://www.w3.org/2000/01/rdf-schema#comment The class of irreflexive properties. .
# http://id.loc.gov/ontologies/bibframe/generation http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/2000/01/rdf-schema#comment The property that determines that two given individuals are different. .
# http://www.w3.org/2002/07/owl#onClass http://www.w3.org/2000/01/rdf-schema#comment The property that determines the class that a qualified object cardinality restriction refers to. .
# http://id.loc.gov/ontologies/bibframe/edition http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/classificationPortion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2002/07/owl#targetValue http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# ub105bL14C20 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Person .
# http://www.w3.org/2002/07/owl#allValuesFrom http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Restriction .
# http://www.w3.org/2002/07/owl#Class http://www.w3.org/2000/01/rdf-schema#label Class .
# http://www.w3.org/2002/07/owl#disjointWith http://www.w3.org/2000/01/rdf-schema#label disjointWith .
# http://www.w3.org/2002/07/owl#distinctMembers http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#AllDifferent .
# http://www.w3.org/2000/01/rdf-schema#Class http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#versionInfo http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#AnnotationProperty .
# http://www.w3.org/2002/07/owl http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/TR/owl2-mapping-to-rdf/ .
# http://www.w3.org/2002/07/owl#datatypeComplementOf http://www.w3.org/2000/01/rdf-schema#label datatypeComplementOf .
# http://id.loc.gov/ontologies/bibframe/geographicCoverage http://www.w3.org/2000/01/rdf-schema#label Geographic coverage .
# ub97bL24C13 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Note .
# http://id.loc.gov/ontologies/bibframe/polarity http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#maxCardinality http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#nonNegativeInteger .
# https://wsburroughs.link/anything-but-routine/4.0/classification/C http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Classification .
# http://www.w3.org/2002/07/owl#withRestrictions http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/musicKey http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://www.w3.org/2000/01/rdf-schema#label The British Journal of Addiction, Vol. 53, No. 2 (January 1957) .
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty http://www.w3.org/2000/01/rdf-schema#label ContainerMembershipProperty .
# http://id.loc.gov/ontologies/bibframe/version http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2000/01/rdf-schema#Container http://www.w3.org/2000/01/rdf-schema#comment The class of RDF containers. .
# http://www.w3.org/2002/07/owl#withRestrictions http://www.w3.org/2000/01/rdf-schema#comment The property that determines the collection of facet-value pairs that define a datatype restriction. .
# http://id.loc.gov/ontologies/bibframe/seriesEnumeration http://www.w3.org/2000/01/rdf-schema#label Series enumeration .
# http://www.w3.org/2002/07/owl#allValuesFrom http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/videoCharacteristic http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#deprecated http://www.w3.org/2000/01/rdf-schema#label deprecated .
# http://id.loc.gov/ontologies/bibframe/legalDate http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/editionEnumeration http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2002/07/owl#cardinality http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/eventContentOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://id.loc.gov/ontologies/bibframe/relatedTo .
# http://www.w3.org/2002/07/owl#AnnotationProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#NamedIndividual http://www.w3.org/2000/01/rdf-schema#comment The class of named individuals. .
# http://www.w3.org/2002/07/owl#sourceIndividual http://www.w3.org/2000/01/rdf-schema#comment The property that determines the subject of a negative property assertion. .
# http://id.loc.gov/ontologies/bibframe/ensemble http://www.w3.org/2004/02/skos/core#definition Ensemble for which a musical work is appropriate. .
# ub97bL30C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#value Burroughs’ first appearance in print under his own name. .
# https://wsburroughs.link/anything-but-routine/4.0/work/C3 http://www.w3.org/2000/01/rdf-schema#label The British Journal of Addiction, Vol. 53, No. 2 (January 1957) .
# http://id.loc.gov/ontologies/bibframe/extent http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#oneOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/eventContentOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/geographicCoverage http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://www.w3.org/2002/07/owl#onDatatype http://www.w3.org/2000/01/rdf-schema#comment The property that determines the datatype that a datatype restriction refers to. .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://www.w3.org/2004/02/skos/core#definition Resource that reproduces another Resource. .
# http://www.w3.org/2002/07/owl#onDatatype http://www.w3.org/2000/01/rdf-schema#label onDatatype .
# http://www.w3.org/2002/07/owl#targetIndividual http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#annotatedProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#ObjectProperty http://www.w3.org/2000/01/rdf-schema#comment The class of object properties. .
# http://www.w3.org/2002/07/owl#bottomObjectProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/edition http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/editionStatement http://www.w3.org/2000/01/rdf-schema#label Edition statement .
# http://www.w3.org/2002/07/owl#IrreflexiveProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#incompatibleWith http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Ontology .
# http://id.loc.gov/ontologies/bibframe/musicSerialNumber http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://id.loc.gov/ontologies/bibframe/hasInstance http://www.w3.org/2002/07/owl#inverseOf http://id.loc.gov/ontologies/bibframe/instanceOf .
# http://www.w3.org/2002/07/owl#SymmetricProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#assertionProperty http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#NegativePropertyAssertion .
# http://www.w3.org/2002/07/owl#distinctMembers http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/2002/07/owl#deprecated http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Resource .
# http://www.w3.org/2002/07/owl#priorVersion http://www.w3.org/2000/01/rdf-schema#label priorVersion .
# http://www.w3.org/2002/07/owl#SymmetricProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#maxQualifiedCardinality http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/productionMethod http://www.w3.org/2004/02/skos/core#definition Process used to produce a resource. .
# http://www.w3.org/2002/07/owl#annotatedProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# ...
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://id.loc.gov/ontologies/bibframe/voice http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/MusicVoice .
# http://www.w3.org/2002/07/owl#disjointUnionOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#TransitiveProperty http://www.w3.org/2000/01/rdf-schema#comment The class of transitive properties. .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/title ub106bL35C14 .
# http://www.w3.org/2002/07/owl#ReflexiveProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#incompatibleWith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#AnnotationProperty .
# http://www.w3.org/2002/07/owl#deprecated http://www.w3.org/2000/01/rdf-schema#comment The annotation property that indicates that a given entity has been deprecated. .
# http://www.w3.org/2002/07/owl#versionIRI http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Ontology .
# http://id.loc.gov/ontologies/bibframe/classificationPortion http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# ub106bL20C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#value C3 .
# https://wsburroughs.link/anything-but-routine/4.0/work/C3 http://id.loc.gov/ontologies/bibframe/contributor ub105bL14C20 .
# ub106bL20C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Identifier .
# ub106bL30C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Note .
# http://www.w3.org/2002/07/owl#DatatypeProperty http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# https://wsburroughs.link/anything-but-routine/4.0/work/C3 http://id.loc.gov/ontologies/bibframe/hasInstance https://wsburroughs.link/anything-but-routine/4.0/instance/C3 .
# http://id.loc.gov/ontologies/bibframe/content http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/Content .
# ub97bL13C20 http://www.w3.org/2000/01/rdf-schema#label William S. Burroughs .
# http://id.loc.gov/ontologies/bibframe/schedulePart http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://id.loc.gov/ontologies/bibframe/soundCharacteristic http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2000/01/rdf-schema#comment http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2002/07/owl#TransitiveProperty http://www.w3.org/2000/01/rdf-schema#label TransitiveProperty .
# http://id.loc.gov/ontologies/bibframe/spanEnd http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Classification .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#inverseOf http://www.w3.org/2000/01/rdf-schema#label inverseOf .
# http://id.loc.gov/ontologies/bibframe/Instance http://www.w3.org/2004/02/skos/core#definition Resource reflecting an individual, material embodiment of a Work. .
# http://www.w3.org/2002/07/owl#AnnotationProperty http://www.w3.org/2000/01/rdf-schema#label AnnotationProperty .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema# .
# http://id.loc.gov/ontologies/bibframe/bookFormat http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#hasValue http://www.w3.org/2000/01/rdf-schema#comment The property that determines the individual that a has-value restriction refers to. .
# http://www.w3.org/2002/07/owl#topObjectProperty http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Thing .
# http://www.w3.org/2002/07/owl#DatatypeProperty http://www.w3.org/2000/01/rdf-schema#comment The class of data properties. .
# http://www.w3.org/2002/07/owl http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/TR/owl2-rdf-based-semantics/#table-axiomatic-properties .
# http://www.w3.org/2002/07/owl#onDataRange http://www.w3.org/2000/01/rdf-schema#label onDataRange .
# http://id.loc.gov/ontologies/bibframe/reproductionOf http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/generation http://www.w3.org/2004/02/skos/core#definition Relationship between an original carrier and the carrier of a reproduction made from the original. .
# http://id.loc.gov/ontologies/bibframe/appliedMaterial http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/hasItem http://www.w3.org/2000/01/rdf-schema#label Has holding .
# http://www.w3.org/2002/07/owl#Axiom http://www.w3.org/2000/01/rdf-schema#comment The class of annotated axioms for which the RDF serialization consists of an annotated subject, predicate and object. .
# http://www.w3.org/2002/07/owl#propertyDisjointWith http://www.w3.org/2000/01/rdf-schema#comment The property that determines that two given properties are disjoint. .
# http://id.loc.gov/ontologies/bibframe/spanEnd http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/appliedMaterial http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/AppliedMaterial .
# http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#seeAlso .
# http://www.w3.org/2002/07/owl#members http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/2002/07/owl#annotatedSource http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#onClass http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/legalDate http://purl.org/dc/terms/modified 2016-04-21 (New) .
# ub106bL24C13 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://id.loc.gov/ontologies/bibframe/Note .
# http://id.loc.gov/ontologies/bibframe/musicMedium http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#OntologyProperty http://www.w3.org/2000/01/rdf-schema#comment The class of ontology properties. .
# http://id.loc.gov/ontologies/bibframe/digitalCharacteristic http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#onDataRange http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Restriction .
# http://id.loc.gov/ontologies/bibframe/historyOfWork http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/legalDate http://www.w3.org/2004/02/skos/core#definition Date of legal work, or promulgation of a law, or signing of a treaty. .
# http://id.loc.gov/ontologies/bibframe/seriesStatement http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/hasExpression http://www.w3.org/2000/01/rdf-schema#range http://id.loc.gov/ontologies/bibframe/Work .
# http://id.loc.gov/ontologies/bibframe/seriesStatement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://www.w3.org/2000/01/rdf-schema# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Ontology .
# http://www.w3.org/2002/07/owl#ObjectProperty http://www.w3.org/2000/01/rdf-schema#label ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/productionMethod http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#datatypeComplementOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#bottomDataProperty http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#versionInfo http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/tableSeq http://www.w3.org/2004/02/skos/core#definition Sequence number or other identifier for an internal classification sub arrangement or add in a classification scheme. .
# http://www.w3.org/2002/07/owl#onDataRange http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://id.loc.gov/ontologies/bibframe/hasInstance http://www.w3.org/2004/02/skos/core#definition Instance is related to described Work. For use to connect Works to Instances in the BIBFRAME structure. .
# http://www.w3.org/2000/01/rdf-schema#seeAlso http://www.w3.org/2000/01/rdf-schema#label seeAlso .
# http://id.loc.gov/ontologies/bibframe/seriesEnumeration http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2000/01/rdf-schema#Container http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Resource .
# http://www.w3.org/2002/07/owl http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/TR/owl2-syntax/ .
# http://id.loc.gov/ontologies/bibframe/hasReproduction http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/subseriesEnumeration http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema#label isDefinedBy .
# http://www.w3.org/2002/07/owl#imports http://www.w3.org/2000/01/rdf-schema#comment The property that is used for importing other ontologies into a given ontology. .
# https://wsburroughs.link/anything-but-routine/4.0/instance/C3 http://id.loc.gov/ontologies/bibframe/classification https://wsburroughs.link/anything-but-routine/4.0/classification/C .
# http://www.w3.org/2002/07/owl#AllDisjointProperties http://www.w3.org/2000/01/rdf-schema#comment The class of collections of pairwise disjoint properties. .
# http://id.loc.gov/ontologies/bibframe/polarity http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://id.loc.gov/ontologies/bibframe/content http://www.w3.org/2000/01/rdf-schema#label Content type .
# http://www.w3.org/2002/07/owl#sameAs http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#annotatedProperty http://www.w3.org/2000/01/rdf-schema#label annotatedProperty .
# http://id.loc.gov/ontologies/bibframe/emulsion http://www.w3.org/2004/02/skos/core#definition Suspension of light-sensitive chemicals used as a coating on a microfilm or microfiche, e.g., silver halide. .
# http://id.loc.gov/ontologies/bibframe/appliedMaterial http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#AllDifferent http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://www.w3.org/2002/07/owl#oneOf http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2002/07/owl# .
# http://id.loc.gov/ontologies/bibframe/reductionRatio http://purl.org/dc/terms/modified 2016-04-21 (New) .
# ub97bL20C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#value C3 .
# http://www.w3.org/2002/07/owl#sourceIndividual http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Thing .
# http://id.loc.gov/ontologies/bibframe/baseMaterial http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://www.w3.org/2002/07/owl#DeprecatedProperty http://www.w3.org/2000/01/rdf-schema#comment The class of deprecated properties. .
# http://id.loc.gov/ontologies/bibframe/edition http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Classification .
# http://www.w3.org/2002/07/owl#deprecated http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Resource .
# http://id.loc.gov/ontologies/bibframe/layout http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#AnnotationProperty http://www.w3.org/2000/01/rdf-schema#comment The class of annotation properties. .
# https://wsburroughs.link/anything-but-routine/4.0/work/C3 http://id.loc.gov/ontologies/bibframe/contributor ub107bL14C20 .
# http://id.loc.gov/ontologies/bibframe/content http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Work .
# http://www.w3.org/2002/07/owl#DeprecatedClass http://www.w3.org/2000/01/rdf-schema#label DeprecatedClass .
# http://id.loc.gov/ontologies/bibframe/hasInstance http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://id.loc.gov/ontologies/bibframe/provisionActivity http://www.w3.org/2004/02/skos/core#definition Place, name, and/or date information relating to the publication, printing, distribution, issue, release, production, etc. of a resource. .
# http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#label range .
# http://id.loc.gov/ontologies/bibframe/digitalCharacteristic http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2002/07/owl#Thing .
# http://id.loc.gov/ontologies/bibframe/subseriesStatement http://purl.org/dc/terms/modified 2016-04-21 (New) .
# http://id.loc.gov/ontologies/bibframe/editionEnumeration http://www.w3.org/2000/01/rdf-schema#label Edition enumeration .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Thing .
# http://www.w3.org/2002/07/owl#disjointUnionOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2002/07/owl#Class .
# http://www.w3.org/2002/07/owl#onProperty http://www.w3.org/2000/01/rdf-schema#comment The property that determines the property that a property restriction refers to. .
# http://www.w3.org/2002/07/owl#Class http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# ub97bL35C14 http://www.w3.org/2000/01/rdf-schema#label The British Journal of Addiction, Vol. 53, No. 2 (January 1957) .
# http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema#comment The defininition of the subject resource. .
# http://www.w3.org/2002/07/owl#maxQualifiedCardinality http://www.w3.org/2000/01/rdf-schema#comment The property that determines the cardinality of a maximum qualified cardinality restriction. .
# http://id.loc.gov/ontologies/bibframe/provisionActivity http://www.w3.org/2000/01/rdf-schema#domain http://id.loc.gov/ontologies/bibframe/Instance .
# http://www.w3.org/2002/07/owl#NamedIndividual http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://id.loc.gov/ontologies/bibframe/tableSeq http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty .
# http://id.loc.gov/ontologies/bibframe/musicSerialNumber http://www.w3.org/2000/01/rdf-schema#label Music serial number .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# ub97bL28C9 http://www.w3.org/1999/02/22-rdf-syntax-ns#value Letter dated “August 3rd, 1956.” .
