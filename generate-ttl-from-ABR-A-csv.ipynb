# %% [markdown]
# ## Load packages, initialize sentence tokenization resource

# %%
import numpy as np, pandas as pd, rdflib, re, nltk, collections
from rdflib.namespace import RDF, RDFS
from rdflib import URIRef, BNode, Literal
from slugify import slugify
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bradleyallen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/bradleyallen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/bradleyallen/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/bradleyallen/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## Load CSV file for ABR A list

# %%
df = pd.read_csv('edited-csv/Schottlaender v4.0 - A.csv')

# %% [markdown]
# ## Extract entity names and features

# %% [markdown]
# ### Normalize all whitespace to spaces in notes

# %%
df['notes'] = df['notes'].str.replace('\s', ' ')

# %% [markdown]
# ### Places

# %%
df['place'] = df['publication'].str.extract('(.+)\:', expand=False)

# %% [markdown]
# ### Publishers

# %%
df['publisher'] = df['publication'].str.extract('\: (.+)', expand=False)

# %% [markdown]
# ### Copyright dates

# %%
df['copyrightDate'] = df['notes'].str.extract('©(\w+)', expand=False)

# %% [markdown]
# ### Identifiers

# %%
df['MaynardAndMiles'] = df['notes'].str.extract('\{M\&M (\S*)\}', expand=False)

# %%
df['Schottlaender'] = df['work'] + df['instance'].str.lower()

# %% [markdown]
# ### Bindings (in progress)

# %%
df['binding'] = df['notes'].str.extract('([A-Z]\S+bound[^.]*)\.', expand=False)
df['binding'] = df['binding'].str.strip()

# %%
df['binding'].value_counts().sort_index()
# Out:
# Hardbound                                                                                                1
# Hardbound (issued without dustjacket)                                                                    2
# Hardbound (issued without dustjacket), and softbound                                                     4
# Hardbound in dustjacket                                                                                 17
# Hardbound in dustjacket (no softbound issued)                                                            7
# Hardbound in dustjacket, and softbound                                                                  19
# Hardbound in dustjacket, issued with compact disc bound in rear                                          1
# Hardbound in tissue dustjacket, and softbound                                                            1
# Hardbound with hand-made orange tissue guards inserted                                                   1
# Hardbound, and softbound                                                                                 3
# Hardbound, issued without dust jacket                                                                    1
# Hardbound, issued without dustjacket                                                                     2
# Hardbound, issued without dustjacket in Side A, white; Side B, black;  matrix number: UB LP 1 A S/S]     1
# Hardbound; handbound (issued without dustjacket in slipcase)                                             1
# Softbound                                                                                               54
# Softbound (no hardbound issued)                                                                         54
# Softbound in dustjacket (no hardbound issued)                                                            4
# Softbound with dustjacket (no hardbound issued)                                                          1
# Softbound; handbound (no hardbound issued)                                                               1
# Staplebound                                                                                              5
# Staplebound (no hardbound issued)                                                                       12
# Staplebound mimeograph  (no hardbound issued)                                                            1
# Staplebound pamphlet                                                                                     2
# Name: binding, dtype: int64

# %% [markdown]
# ### Promotional materials (in progress)

# %%
df['promotionalMaterial'] = df['notes'].str.extract(' 1. (\[.+$)', expand=False)

# %%
df[df.promotionalMaterial.notnull()][['Schottlaender', 'promotionalMaterial']]
# Out:
#     Schottlaender                                promotionalMaterial
# 12            A2b  [Prospectus]. New York: Grove Press, [1962]. P...
# 95           A24a  [Prospectus]. In English and French. Ingatesto...
# 96           A24b  [Prospectus]. Göttingen: Expanded Media Editio...
# 140          A42a  [Prospectus]. Santa Barbara, Calif.: Bradford ...
# 160          A54a  [Promotional Postcard]. San Francisco: City Li...
# 162          A56a  [Press Kit]. New York: Holt, Rinehart and Wins...
# 174          A59a  [Press Release]. New York: Viking Penguin, [19...
# 190          A65a  [Promotional Postcard] a. Berkeley, Calif.: Sm...
# 191          A66a  [Prospectus]. New York: Whitney Museum of Amer...
# 192          A66b  [Promotional Poster]. [New York]: High Risk Bo...
# 213          A82a  [Promotional Postcard]. [New York: The Center ...

# %% [markdown]
# ### Squeeze even more data out of notes using more nuanced NLP (in progress)

# %%
instances = df.where((pd.notnull(df)), None).to_dict('records')
for i in instances:
    print(i['Schottlaender'])
    notes = i['notes']
    if notes:
        notes_text = nltk.sent_tokenize(notes)
        for sentence in notes_text:
            tokenized = nltk.word_tokenize(sentence)
            tagged = nltk.pos_tag(tokenized)
            print(sentence)
            print(f"    {tagged}")
# Out:
# A1a
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A1a} Published under the pseudonym William Lee.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A1a', 'NNP'), ('}', ')'), ('Published', 'VBN'), ('under', 'IN'), ('the', 'DT'), ('pseudonym', 'NN'), ('William', 'NNP'), ('Lee', 'NNP'), ('.', '.')]
# Title on cover: Junkie: Confessions of an Unredeemed Drug Addict.
#     [('Title', 'NN'), ('on', 'IN'), ('cover', 'NN'), (':', ':'), ('Junkie', 'NN'), (':', ':'), ('Confessions', 'NNS'), ('of', 'IN'), ('an', 'DT'), ('Unredeemed', 'NNP'), ('Drug', 'NNP'), ('Addict', 'NNP'), ('.', '.')]
# Issued bound back-to-back with Maurice Helbrant’s Narcotic Agent.
#     [('Issued', 'VBN'), ('bound', 'IN'), ('back-to-back', 'NN'), ('with', 'IN'), ('Maurice', 'NNP'), ('Helbrant', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('Narcotic', 'JJ'), ('Agent', 'NNP'), ('.', '.')]
# “For the protection of the reader, we have inserted occasional parenthetical notes [i.e., bracketed editor’s notes] to indicate where the author clearly departs from accepted medical fact or makes other statements in an effort to justify his actions.”—Publisher’s Note.
#     [('“', 'NN'), ('For', 'IN'), ('the', 'DT'), ('protection', 'NN'), ('of', 'IN'), ('the', 'DT'), ('reader', 'NN'), (',', ','), ('we', 'PRP'), ('have', 'VBP'), ('inserted', 'VBN'), ('occasional', 'JJ'), ('parenthetical', 'JJ'), ('notes', 'NNS'), ('[', 'VBP'), ('i.e.', 'NN'), (',', ','), ('bracketed', 'VBD'), ('editor', 'NN'), ('’', 'NN'), ('s', 'NN'), ('notes', 'NNS'), (']', 'VBP'), ('to', 'TO'), ('indicate', 'VB'), ('where', 'WRB'), ('the', 'DT'), ('author', 'NN'), ('clearly', 'RB'), ('departs', 'VBZ'), ('from', 'IN'), ('accepted', 'VBN'), ('medical', 'JJ'), ('fact', 'NN'), ('or', 'CC'), ('makes', 'VBZ'), ('other', 'JJ'), ('statements', 'NNS'), ('in', 'IN'), ('an', 'DT'), ('effort', 'NN'), ('to', 'TO'), ('justify', 'VB'), ('his', 'PRP$'), ('actions.', 'NN'), ('”', 'VBZ'), ('—Publisher', 'CC'), ('’', 'JJ'), ('s', 'JJ'), ('Note', 'NN'), ('.', '.')]
# Autograph note at end of Burroughs’ untitled typescript, examined at Columbia University’s Rare Books and Manuscripts Library: “End of Part I, Junk.” “There are major differences between this manuscript and the first [Ace] edition.
#     [('Autograph', 'NNP'), ('note', 'NN'), ('at', 'IN'), ('end', 'NN'), ('of', 'IN'), ('Burroughs', 'NNP'), ('’', 'NNP'), ('untitled', 'VBD'), ('typescript', 'NN'), (',', ','), ('examined', 'VBN'), ('at', 'IN'), ('Columbia', 'NNP'), ('University', 'NNP'), ('’', 'NNP'), ('s', 'PRP'), ('Rare', 'NNP'), ('Books', 'NNP'), ('and', 'CC'), ('Manuscripts', 'NNP'), ('Library', 'NNP'), (':', ':'), ('“', 'JJ'), ('End', 'NN'), ('of', 'IN'), ('Part', 'NNP'), ('I', 'PRP'), (',', ','), ('Junk.', 'NNP'), ('”', 'NNP'), ('“', 'NNP'), ('There', 'EX'), ('are', 'VBP'), ('major', 'JJ'), ('differences', 'NNS'), ('between', 'IN'), ('this', 'DT'), ('manuscript', 'NN'), ('and', 'CC'), ('the', 'DT'), ('first', 'JJ'), ('[', 'JJ'), ('Ace', 'NNP'), (']', 'NNP'), ('edition', 'NN'), ('.', '.')]
# This manuscript was used by Penguin Books in the issuing of their ‘unexpurgated’ edition of 1977 [below], despite which there are many differences, some important, between the manuscript and that version.”—Bookseller’s note laid in to Columbia’s typescript.
#     [('This', 'DT'), ('manuscript', 'NN'), ('was', 'VBD'), ('used', 'VBN'), ('by', 'IN'), ('Penguin', 'NNP'), ('Books', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('issuing', 'NN'), ('of', 'IN'), ('their', 'PRP$'), ('‘', 'NN'), ('unexpurgated', 'VBD'), ('’', 'JJ'), ('edition', 'NN'), ('of', 'IN'), ('1977', 'CD'), ('[', 'NNP'), ('below', 'IN'), (']', 'NNP'), (',', ','), ('despite', 'IN'), ('which', 'WDT'), ('there', 'EX'), ('are', 'VBP'), ('many', 'JJ'), ('differences', 'NNS'), (',', ','), ('some', 'DT'), ('important', 'JJ'), (',', ','), ('between', 'IN'), ('the', 'DT'), ('manuscript', 'NN'), ('and', 'CC'), ('that', 'IN'), ('version.', 'JJ'), ('”', 'NNP'), ('—Bookseller', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('note', 'NN'), ('laid', 'NN'), ('in', 'IN'), ('to', 'TO'), ('Columbia', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('typescript', 'NN'), ('.', '.')]
# A1b
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A1b}  Published under the pseudonym William Lee.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A1b', 'NNP'), ('}', ')'), ('Published', 'VBN'), ('under', 'IN'), ('the', 'DT'), ('pseudonym', 'NN'), ('William', 'NNP'), ('Lee', 'NNP'), ('.', '.')]
# First standalone publication of Junkie.
#     [('First', 'RB'), ('standalone', 'JJ'), ('publication', 'NN'), ('of', 'IN'), ('Junkie', 'NNP'), ('.', '.')]
# Subsequently withdrawn and remaining copies pulped.
#     [('Subsequently', 'RB'), ('withdrawn', 'VBN'), ('and', 'CC'), ('remaining', 'VBG'), ('copies', 'NNS'), ('pulped', 'VBN'), ('.', '.')]
# [Miles]
#     [('[', 'JJ'), ('Miles', 'NNP'), (']', 'NN')]
# A1c
# Foreword by Carl Solomon.
#     [('Foreword', 'NN'), ('by', 'IN'), ('Carl', 'NNP'), ('Solomon', 'NNP'), ('.', '.')]
# (Ace Star, K202) Softbound (no hardbound issued).
#     [('(', '('), ('Ace', 'NNP'), ('Star', 'NNP'), (',', ','), ('K202', 'NNP'), (')', ')'), ('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A1c}  1st separate U.S. publication, and 1st   1st state: .50¢ cover price; 2nd state: (Ace Star, 41841) and .60¢ cover price.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A1c', 'NNP'), ('}', ')'), ('1st', 'CD'), ('separate', 'JJ'), ('U.S.', 'NNP'), ('publication', 'NN'), (',', ','), ('and', 'CC'), ('1st', 'CD'), ('1st', 'CD'), ('state', 'NN'), (':', ':'), ('.50¢', 'NN'), ('cover', 'NN'), ('price', 'NN'), (';', ':'), ('2nd', 'CD'), ('state', 'NN'), (':', ':'), ('(', '('), ('Ace', 'NNP'), ('Star', 'NNP'), (',', ','), ('41841', 'CD'), (')', ')'), ('and', 'CC'), ('.60¢', '$'), ('cover', 'JJ'), ('price', 'NN'), ('.', '.')]
# [BeatBooks 51]    Reprinted in 1970 and 1973 (the latter with a different cover).
#     [('[', 'JJ'), ('BeatBooks', 'NNP'), ('51', 'CD'), (']', 'NNP'), ('Reprinted', 'VBN'), ('in', 'IN'), ('1970', 'CD'), ('and', 'CC'), ('1973', 'CD'), ('(', '('), ('the', 'DT'), ('latter', 'NN'), ('with', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('cover', 'NN'), (')', ')'), ('.', '.')]
# [M&M]
#     [('[', 'NNP'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), (']', 'NN')]
# A1d
# (The Olympia Press Travellers Companion Series, No.
#     [('(', '('), ('The', 'DT'), ('Olympia', 'NNP'), ('Press', 'NNP'), ('Travellers', 'NNP'), ('Companion', 'NNP'), ('Series', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 114).
#     [('114', 'CD'), (')', ')'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A1d}  Issued in clear tissue jacket.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A1d', 'NNP'), ('}', ')'), ('Issued', 'NNP'), ('in', 'IN'), ('clear', 'JJ'), ('tissue', 'NN'), ('jacket', 'NN'), ('.', '.')]
# [PBA 327] In this edition, “Notes,” originally printed in the text (see A1A above), are printed in a separate section at the end—out of context and preceding the newly added “Glossary.” Reprinted in 1969 and 1972 with different covers.
#     [('[', 'JJ'), ('PBA', 'NNP'), ('327', 'CD'), (']', 'NN'), ('In', 'IN'), ('this', 'DT'), ('edition', 'NN'), (',', ','), ('“', 'JJ'), ('Notes', 'NNS'), (',', ','), ('”', 'NNP'), ('originally', 'RB'), ('printed', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('text', 'NN'), ('(', '('), ('see', 'VB'), ('A1A', 'NNP'), ('above', 'IN'), (')', ')'), (',', ','), ('are', 'VBP'), ('printed', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('separate', 'JJ'), ('section', 'NN'), ('at', 'IN'), ('the', 'DT'), ('end—out', 'NN'), ('of', 'IN'), ('context', 'NN'), ('and', 'CC'), ('preceding', 'VBG'), ('the', 'DT'), ('newly', 'RB'), ('added', 'VBN'), ('“', 'NN'), ('Glossary.', 'NNP'), ('”', 'NNP'), ('Reprinted', 'NNP'), ('in', 'IN'), ('1969', 'CD'), ('and', 'CC'), ('1972', 'CD'), ('with', 'IN'), ('different', 'JJ'), ('covers', 'NNS'), ('.', '.')]
# [M&M]
#     [('[', 'NNP'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), (']', 'NN')]
# A1e
# Foreword by Carl Solomon.
#     [('Foreword', 'NN'), ('by', 'IN'), ('Carl', 'NNP'), ('Solomon', 'NNP'), ('.', '.')]
# Preface by Burroughs.
#     [('Preface', 'NN'), ('by', 'IN'), ('Burroughs', 'NNP'), ('.', '.')]
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# {M&M A1e} Includes “Glossary.” “The first, and only, English-language edition in hardcover.” [BeatBooks 65]
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A1e', 'NNP'), ('}', ')'), ('Includes', 'NNP'), ('“', 'NNP'), ('Glossary.', 'NNP'), ('”', 'NNP'), ('“', 'VBD'), ('The', 'DT'), ('first', 'JJ'), (',', ','), ('and', 'CC'), ('only', 'RB'), (',', ','), ('English-language', 'JJ'), ('edition', 'NN'), ('in', 'IN'), ('hardcover.', 'NN'), ('”', 'NNP'), ('[', 'NNP'), ('BeatBooks', 'NNP'), ('65', 'CD'), (']', 'NN')]
# A1f
# With an introduction by Allen Ginsberg.
#     [('With', 'IN'), ('an', 'DT'), ('introduction', 'NN'), ('by', 'IN'), ('Allen', 'NNP'), ('Ginsberg', 'NNP'), ('.', '.')]
# 1st complete and unexpurgated ed.
#     [('1st', 'CD'), ('complete', 'JJ'), ('and', 'CC'), ('unexpurgated', 'JJ'), ('ed', 'NN'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# Later 1977 printing with different cover design.
#     [('Later', 'RB'), ('1977', 'CD'), ('printing', 'VBG'), ('with', 'IN'), ('different', 'JJ'), ('cover', 'NN'), ('design', 'NN'), ('.', '.')]
# [Shoaf 1]
#     [('[', 'JJ'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'NN')]
# A1g
# A1h
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A1i
# Edited and with an Introduction by Oliver Harris.
#     [('Edited', 'VBN'), ('and', 'CC'), ('with', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('Oliver', 'NNP'), ('Harris', 'NNP'), ('.', '.')]
# 50th Anniversary ed.
#     [('50th', 'JJ'), ('Anniversary', 'NNP'), ('ed', 'NN'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# “Apart from making just over a hundred small corrections or changes, this present edition adds to Junky approximately the same amount of new material (around four thousand words) as Junky added to Junkie, but the way it does is, and had to be, quite different.”—Introduction.
#     [('“', 'JJ'), ('Apart', 'NNP'), ('from', 'IN'), ('making', 'VBG'), ('just', 'RB'), ('over', 'IN'), ('a', 'DT'), ('hundred', 'CD'), ('small', 'JJ'), ('corrections', 'NNS'), ('or', 'CC'), ('changes', 'NNS'), (',', ','), ('this', 'DT'), ('present', 'JJ'), ('edition', 'NN'), ('adds', 'VBZ'), ('to', 'TO'), ('Junky', 'NNP'), ('approximately', 'RB'), ('the', 'DT'), ('same', 'JJ'), ('amount', 'NN'), ('of', 'IN'), ('new', 'JJ'), ('material', 'NN'), ('(', '('), ('around', 'IN'), ('four', 'CD'), ('thousand', 'NN'), ('words', 'NNS'), (')', ')'), ('as', 'IN'), ('Junky', 'NNP'), ('added', 'VBD'), ('to', 'TO'), ('Junkie', 'NNP'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('way', 'NN'), ('it', 'PRP'), ('does', 'VBZ'), ('is', 'VBZ'), (',', ','), ('and', 'CC'), ('had', 'VBD'), ('to', 'TO'), ('be', 'VB'), (',', ','), ('quite', 'RB'), ('different.', 'JJ'), ('”', 'JJ'), ('—Introduction', 'NN'), ('.', '.')]
# A1j
# Edited and with an Introduction by Oliver Harris.
#     [('Edited', 'VBN'), ('and', 'CC'), ('with', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('Oliver', 'NNP'), ('Harris', 'NNP'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A1k
# Edited and with an Introduction by Oliver Harris.
#     [('Edited', 'VBN'), ('and', 'CC'), ('with', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('Oliver', 'NNP'), ('Harris', 'NNP'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A2a
# (The Travellers Companion Series, No.
#     [('(', '('), ('The', 'DT'), ('Travellers', 'NNPS'), ('Companion', 'NNP'), ('Series', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 76) Softbound in dustjacket (no hardbound issued).
#     [('76', 'CD'), (')', ')'), ('Softbound', 'NN'), ('in', 'IN'), ('dustjacket', 'NN'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A2a} Dustjacket designed by Burroughs.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2a', 'NNP'), ('}', ')'), ('Dustjacket', 'NNP'), ('designed', 'VBN'), ('by', 'IN'), ('Burroughs', 'NNP'), ('.', '.')]
# First copies printed issued without dustjacket.
#     [('First', 'NNP'), ('copies', 'NNS'), ('printed', 'VBD'), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# [M&M]  1st printing comprised two “issues:”  1st issue: Price (“Francs: 1,500”) printed in lower right corner of back cover.
#     [('[', 'NNP'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), (']', 'VBZ'), ('1st', 'CD'), ('printing', 'NN'), ('comprised', 'VBD'), ('two', 'CD'), ('“', 'JJ'), ('issues', 'NNS'), (':', ':'), ('”', 'VB'), ('1st', 'CD'), ('issue', 'NN'), (':', ':'), ('Price', 'NNP'), ('(', '('), ('“', 'JJ'), ('Francs', 'NNP'), (':', ':'), ('1,500', 'CD'), ('”', 'NN'), (')', ')'), ('printed', 'VBD'), ('in', 'IN'), ('lower', 'JJR'), ('right', 'NN'), ('corner', 'NN'), ('of', 'IN'), ('back', 'JJ'), ('cover', 'NN'), ('.', '.')]
# 2nd issue: Price (“New Price NF 18”) stamped over old price in lower right corner of back cover, following the revaluation of the franc in January 1960.
#     [('2nd', 'CD'), ('issue', 'NN'), (':', ':'), ('Price', 'NNP'), ('(', '('), ('“', 'JJ'), ('New', 'NNP'), ('Price', 'NNP'), ('NF', 'NNP'), ('18', 'CD'), ('”', 'NNP'), (')', ')'), ('stamped', 'VBD'), ('over', 'IN'), ('old', 'JJ'), ('price', 'NN'), ('in', 'IN'), ('lower', 'JJR'), ('right', 'NN'), ('corner', 'NN'), ('of', 'IN'), ('back', 'JJ'), ('cover', 'NN'), (',', ','), ('following', 'VBG'), ('the', 'DT'), ('revaluation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('franc', 'NN'), ('in', 'IN'), ('January', 'NNP'), ('1960', 'CD'), ('.', '.')]
# 2nd printing [not to be confused with the “second issue” of the first printing (above)] issued without  dustjacket or decorative border around title page, and with price (“18 francs”) printed on back cover.
#     [('2nd', 'CD'), ('printing', 'VBG'), ('[', 'NN'), ('not', 'RB'), ('to', 'TO'), ('be', 'VB'), ('confused', 'VBN'), ('with', 'IN'), ('the', 'DT'), ('“', 'JJ'), ('second', 'JJ'), ('issue', 'NN'), ('”', 'NN'), ('of', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('printing', 'NN'), ('(', '('), ('above', 'IN'), (')', ')'), (']', 'VBP'), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), ('or', 'CC'), ('decorative', 'JJ'), ('border', 'NN'), ('around', 'IN'), ('title', 'JJ'), ('page', 'NN'), (',', ','), ('and', 'CC'), ('with', 'IN'), ('price', 'NN'), ('(', '('), ('“', 'JJ'), ('18', 'CD'), ('francs', 'NNS'), ('”', 'NN'), (')', ')'), ('printed', 'VBD'), ('on', 'IN'), ('back', 'JJ'), ('cover', 'NN'), ('.', '.')]
# 3rd printing (1965) issued without dustjacket or decorative border around title page, and with price (“Francs: h18”) printed on back cover.
#     [('3rd', 'CD'), ('printing', 'NN'), ('(', '('), ('1965', 'CD'), (')', ')'), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), ('or', 'CC'), ('decorative', 'JJ'), ('border', 'NN'), ('around', 'IN'), ('title', 'JJ'), ('page', 'NN'), (',', ','), ('and', 'CC'), ('with', 'IN'), ('price', 'NN'), ('(', '('), ('“', 'JJ'), ('Francs', 'NNP'), (':', ':'), ('h18', 'NN'), ('”', 'NN'), (')', ')'), ('printed', 'VBD'), ('on', 'IN'), ('back', 'JJ'), ('cover', 'NN'), ('.', '.')]
# A2b
# ©1959.
#     [('©1959', 'NN'), ('.', '.')]
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# {M&M A2b}  “The text in this edition differs quite extensively from the Olympia first edition.” [BeatBooks 65]  Includes, at beginning as “Introduction,” “Deposition: Testimony Concerning a Sickness” [originally published in Evergreen Review, Vol.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2b', 'NNP'), ('}', ')'), ('“', 'VBZ'), ('The', 'DT'), ('text', 'NN'), ('in', 'IN'), ('this', 'DT'), ('edition', 'NN'), ('differs', 'VBZ'), ('quite', 'RB'), ('extensively', 'RB'), ('from', 'IN'), ('the', 'DT'), ('Olympia', 'NNP'), ('first', 'JJ'), ('edition.', 'NN'), ('”', 'NNP'), ('[', 'NNP'), ('BeatBooks', 'NNP'), ('65', 'CD'), (']', 'NNP'), ('Includes', 'NNP'), (',', ','), ('at', 'IN'), ('beginning', 'VBG'), ('as', 'IN'), ('“', 'JJ'), ('Introduction', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('Deposition', 'NNP'), (':', ':'), ('Testimony', 'NN'), ('Concerning', 'VBG'), ('a', 'DT'), ('Sickness', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('Evergreen', 'NNP'), ('Review', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 4, No.
#     [('4', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 11 (January-February 1960); see Section C below] and, at end as “Appendix,” “Letter from a Master Addict to Dangerous Drugs” [originally published in The British Journal of Addiction, Vol.
#     [('11', 'CD'), ('(', '('), ('January-February', 'JJ'), ('1960', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('and', 'CC'), (',', ','), ('at', 'IN'), ('end', 'NN'), ('as', 'IN'), ('“', 'JJ'), ('Appendix', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('Letter', 'NNP'), ('from', 'IN'), ('a', 'DT'), ('Master', 'NNP'), ('Addict', 'NNP'), ('to', 'TO'), ('Dangerous', 'NNP'), ('Drugs', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('The', 'DT'), ('British', 'JJ'), ('Journal', 'NNP'), ('of', 'IN'), ('Addiction', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 53, No.
#     [('53', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 2 (January 1957); see Section C below].
#     [('2', 'CD'), ('(', '('), ('January', 'NNP'), ('1957', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('.', '.')]
# Some copies issued in wraparound band.
#     [('Some', 'DT'), ('copies', 'NNS'), ('issued', 'VBN'), ('in', 'IN'), ('wraparound', 'JJ'), ('band', 'NN'), ('.', '.')]
# [M&M]  “First issue jacket [printed] with no zip code on rear panel and no roman [sic] numerals on lower spine near back panel.” [PBA 327]  2nd printing: dustjacket identical to 1st printing; “second printing” noted on collation page.
#     [('[', 'NNP'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), (']', 'NNP'), ('“', 'NNP'), ('First', 'NNP'), ('issue', 'NN'), ('jacket', 'NN'), ('[', 'NNP'), ('printed', 'VBD'), (']', 'NNP'), ('with', 'IN'), ('no', 'DT'), ('zip', 'NN'), ('code', 'NN'), ('on', 'IN'), ('rear', 'JJ'), ('panel', 'NN'), ('and', 'CC'), ('no', 'DT'), ('roman', 'NN'), ('[', 'VBZ'), ('sic', 'JJ'), (']', 'JJ'), ('numerals', 'NNS'), ('on', 'IN'), ('lower', 'JJR'), ('spine', 'NN'), ('near', 'IN'), ('back', 'JJ'), ('panel.', 'NN'), ('”', 'NN'), ('[', 'NNP'), ('PBA', 'NNP'), ('327', 'CD'), (']', 'VBD'), ('2nd', 'CD'), ('printing', 'NN'), (':', ':'), ('dustjacket', 'NN'), ('identical', 'JJ'), ('to', 'TO'), ('1st', 'CD'), ('printing', 'NN'), (';', ':'), ('“', 'CC'), ('second', 'JJ'), ('printing', 'NN'), ('”', 'NN'), ('noted', 'VBD'), ('on', 'IN'), ('collation', 'NN'), ('page', 'NN'), ('.', '.')]
# [Shoaf 1]  3rd–7th printings: lower-case Roman numeral printing enumeration on rear panel of dustjacket.
#     [('[', 'JJ'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'VBD'), ('3rd–7th', 'CD'), ('printings', 'NNS'), (':', ':'), ('lower-case', 'JJ'), ('Roman', 'NNP'), ('numeral', 'JJ'), ('printing', 'NN'), ('enumeration', 'NN'), ('on', 'IN'), ('rear', 'JJ'), ('panel', 'NN'), ('of', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# [Shoaf 1]  8th–15th printings: lower-case Roman numeral printing enumeration on rear panel of dustjacket, Grove Press catalog number [GP 244] at bottom of spine, Zip code in publisher’s address.
#     [('[', 'JJ'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'VBD'), ('8th–15th', 'CD'), ('printings', 'NNS'), (':', ':'), ('lower-case', 'JJ'), ('Roman', 'NNP'), ('numeral', 'JJ'), ('printing', 'NN'), ('enumeration', 'NN'), ('on', 'IN'), ('rear', 'JJ'), ('panel', 'NN'), ('of', 'IN'), ('dustjacket', 'NN'), (',', ','), ('Grove', 'NNP'), ('Press', 'NNP'), ('catalog', 'NN'), ('number', 'NN'), ('[', 'NNP'), ('GP', 'NNP'), ('244', 'CD'), (']', 'NN'), ('at', 'IN'), ('bottom', 'NN'), ('of', 'IN'), ('spine', 'NN'), (',', ','), ('Zip', 'NNP'), ('code', 'NN'), ('in', 'IN'), ('publisher', 'NN'), ('’', 'NNP'), ('s', 'NN'), ('address', 'NN'), ('.', '.')]
# [Shoaf 1]  1.
#     [('[', 'JJ'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'NN'), ('1', 'CD'), ('.', '.')]
# [Prospectus].
#     [('[', 'NN'), ('Prospectus', 'NNP'), (']', 'NNP'), ('.', '.')]
# New York: Grove Press, [1962].
#     [('New', 'NNP'), ('York', 'NNP'), (':', ':'), ('Grove', 'NNP'), ('Press', 'NNP'), (',', ','), ('[', 'JJ'), ('1962', 'CD'), (']', 'NN'), ('.', '.')]
# Pamphlet.
#     [('Pamphlet', 'NN'), ('.', '.')]
# {M&M F7}  Contains reviews of and an excerpt from Naked Lunch.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('F7', 'NNP'), ('}', ')'), ('Contains', 'NNP'), ('reviews', 'NNS'), ('of', 'IN'), ('and', 'CC'), ('an', 'DT'), ('excerpt', 'NN'), ('from', 'IN'), ('Naked', 'NNP'), ('Lunch', 'NNP'), ('.', '.')]
# Reviews and comments by: Terry Southern, E. S. Seldon, John Ciardi, Norman Mailer, Robert Lowell, and Jack Kerouac.
#     [('Reviews', 'NNS'), ('and', 'CC'), ('comments', 'NNS'), ('by', 'IN'), (':', ':'), ('Terry', 'NNP'), ('Southern', 'NNP'), (',', ','), ('E.', 'NNP'), ('S.', 'NNP'), ('Seldon', 'NNP'), (',', ','), ('John', 'NNP'), ('Ciardi', 'NNP'), (',', ','), ('Norman', 'NNP'), ('Mailer', 'NNP'), (',', ','), ('Robert', 'NNP'), ('Lowell', 'NNP'), (',', ','), ('and', 'CC'), ('Jack', 'NNP'), ('Kerouac', 'NNP'), ('.', '.')]
# Limited to 100 copies.
#     [('Limited', 'VBN'), ('to', 'TO'), ('100', 'CD'), ('copies', 'NNS'), ('.', '.')]
# [PBA 198]
#     [('[', 'JJ'), ('PBA', 'NNP'), ('198', 'CD'), (']', 'NN')]
# A2c
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# “Taiwan piracy of Grove Press first edition, smaller in both height and width than the Grove edition and thinner as well, but having the same dust jacket design, printed on cheap paper, some copies with Taiwan Booksellers’ stamp on rear leaf.” [Shoaf 1]
#     [('“', 'JJ'), ('Taiwan', 'NNP'), ('piracy', 'NN'), ('of', 'IN'), ('Grove', 'NNP'), ('Press', 'NNP'), ('first', 'JJ'), ('edition', 'NN'), (',', ','), ('smaller', 'JJR'), ('in', 'IN'), ('both', 'DT'), ('height', 'NN'), ('and', 'CC'), ('width', 'NN'), ('than', 'IN'), ('the', 'DT'), ('Grove', 'NNP'), ('edition', 'NN'), ('and', 'CC'), ('thinner', 'NN'), ('as', 'RB'), ('well', 'RB'), (',', ','), ('but', 'CC'), ('having', 'VBG'), ('the', 'DT'), ('same', 'JJ'), ('dust', 'NN'), ('jacket', 'NN'), ('design', 'NN'), (',', ','), ('printed', 'VBN'), ('on', 'IN'), ('cheap', 'JJ'), ('paper', 'NN'), (',', ','), ('some', 'DT'), ('copies', 'NNS'), ('with', 'IN'), ('Taiwan', 'NNP'), ('Booksellers', 'NNP'), ('’', 'NNP'), ('stamp', 'NN'), ('on', 'IN'), ('rear', 'JJ'), ('leaf.', 'JJ'), ('”', 'NN'), ('[', 'NNP'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'NN')]
# A2d
# ©1959.
#     [('©1959', 'NN'), ('.', '.')]
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# {M&M A2c} Cover photo of Burroughs by Ian Sommerville.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2c', 'NNP'), ('}', ')'), ('Cover', 'NNP'), ('photo', 'NN'), ('of', 'IN'), ('Burroughs', 'NNP'), ('by', 'IN'), ('Ian', 'NNP'), ('Sommerville', 'NNP'), ('.', '.')]
# Reprinted 1965 (3 times: February, March, August), 1966, and 1970.
#     [('Reprinted', 'VBN'), ('1965', 'CD'), ('(', '('), ('3', 'CD'), ('times', 'NNS'), (':', ':'), ('February', 'NNP'), (',', ','), ('March', 'NNP'), (',', ','), ('August', 'NNP'), (')', ')'), (',', ','), ('1966', 'CD'), (',', ','), ('and', 'CC'), ('1970', 'CD'), ('.', '.')]
# A2e
# 1st Evergreen Black Cat ed.
#     [('1st', 'CD'), ('Evergreen', 'JJ'), ('Black', 'NNP'), ('Cat', 'NNP'), ('ed', 'NN'), ('.', '.')]
# (An Evergreen Black Cat Book, BC-115) ©1959.
#     [('(', '('), ('An', 'DT'), ('Evergreen', 'NNP'), ('Black', 'NNP'), ('Cat', 'NNP'), ('Book', 'NNP'), (',', ','), ('BC-115', 'NNP'), (')', ')'), ('©1959', 'NN'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A2d} Includes, at beginning, “Naked Lunch on Trial: The Massachusetts Supreme Court Decision and Excerpts from the Boston Trial” (an expansion of “The Boston Trial of Naked Lunch” [originally published in Evergreen Review, Vol.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2d', 'NNP'), ('}', ')'), ('Includes', 'NNP'), (',', ','), ('at', 'IN'), ('beginning', 'VBG'), (',', ','), ('“', 'JJ'), ('Naked', 'NNP'), ('Lunch', 'NN'), ('on', 'IN'), ('Trial', 'NN'), (':', ':'), ('The', 'DT'), ('Massachusetts', 'NNP'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('Decision', 'NNP'), ('and', 'CC'), ('Excerpts', 'NNP'), ('from', 'IN'), ('the', 'DT'), ('Boston', 'NNP'), ('Trial', 'NNP'), ('”', 'NNP'), ('(', '('), ('an', 'DT'), ('expansion', 'NN'), ('of', 'IN'), ('“', 'NNP'), ('The', 'DT'), ('Boston', 'NNP'), ('Trial', 'NNP'), ('of', 'IN'), ('Naked', 'NNP'), ('Lunch', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('Evergreen', 'NNP'), ('Review', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 9, No.
#     [('9', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 36 (June 1965); see Section C below]) and “Deposition: Testimony Concerning a Sickness” [originally published in Evergreen Review, Vol.
#     [('36', 'CD'), ('(', '('), ('June', 'NNP'), ('1965', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), (')', ')'), ('and', 'CC'), ('“', 'JJ'), ('Deposition', 'NN'), (':', ':'), ('Testimony', 'NN'), ('Concerning', 'VBG'), ('a', 'DT'), ('Sickness', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('Evergreen', 'NNP'), ('Review', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 4, No.
#     [('4', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 11 (January-February 1960); see Section C below], and, at end as “Appendix,” “Letter from a Master Addict to Dangerous Drugs” [originally published in The British Journal of Addiction, Vol.
#     [('11', 'CD'), ('(', '('), ('January-February', 'JJ'), ('1960', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), (',', ','), ('and', 'CC'), (',', ','), ('at', 'IN'), ('end', 'NN'), ('as', 'IN'), ('“', 'JJ'), ('Appendix', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('Letter', 'NNP'), ('from', 'IN'), ('a', 'DT'), ('Master', 'NNP'), ('Addict', 'NNP'), ('to', 'TO'), ('Dangerous', 'NNP'), ('Drugs', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('The', 'DT'), ('British', 'JJ'), ('Journal', 'NNP'), ('of', 'IN'), ('Addiction', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 53, No.
#     [('53', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 2 (January 1957); see Section C below].
#     [('2', 'CD'), ('(', '('), ('January', 'NNP'), ('1957', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('.', '.')]
# Reprinted several (17?)
#     [('Reprinted', 'VBN'), ('several', 'JJ'), ('(', '('), ('17', 'CD'), ('?', '.'), (')', ')')]
# times.
#     [('times', 'NNS'), ('.', '.')]
# A2f
# ©1959.
#     [('©1959', 'NN'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A2e} Reprinted in 1969, 1972, and 1974 (with different cover).
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2e', 'NNP'), ('}', ')'), ('Reprinted', 'VBN'), ('in', 'IN'), ('1969', 'CD'), (',', ','), ('1972', 'CD'), (',', ','), ('and', 'CC'), ('1974', 'CD'), ('(', '('), ('with', 'IN'), ('different', 'JJ'), ('cover', 'NN'), (')', ')'), ('.', '.')]
# A2g
# Hardbound in dustjacket, and softbound.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('and', 'CC'), ('softbound', 'NN'), ('.', '.')]
# {M&M A2f}
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2f', 'NNP'), ('}', ')')]
# A2h
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A2g}
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A2g', 'NNP'), ('}', ')')]
# A2i
# With a Foreword by John Calder.
#     [('With', 'IN'), ('a', 'DT'), ('Foreword', 'NNP'), ('by', 'IN'), ('John', 'NNP'), ('Calder', 'NNP'), ('.', '.')]
# (A Calderbook, CB 380) Softbound (no hardbound issued).
#     [('(', '('), ('A', 'DT'), ('Calderbook', 'NNP'), (',', ','), ('CB', 'NNP'), ('380', 'CD'), (')', ')'), ('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# “A new edition containing the ‘Ugh’ correspondence [originally printed in the Times Literary Supplement No.
#     [('“', 'VB'), ('A', 'DT'), ('new', 'JJ'), ('edition', 'NN'), ('containing', 'VBG'), ('the', 'DT'), ('‘', 'NNP'), ('Ugh', 'NNP'), ('’', 'NNP'), ('correspondence', 'NN'), ('[', 'NNP'), ('originally', 'RB'), ('printed', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('Times', 'NNP'), ('Literary', 'NNP'), ('Supplement', 'NNP'), ('No', 'NNP'), ('.', '.')]
# 3,230 (23 January 1964); see Section C below].”—Cover.
#     [('3,230', 'CD'), ('(', '('), ('23', 'CD'), ('January', 'NNP'), ('1964', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('.', '.'), ('”', 'NN'), ('—Cover', 'NN'), ('.', '.')]
# A2j
# With an introduction by Jennie Skerl.
#     [('With', 'IN'), ('an', 'DT'), ('introduction', 'NN'), ('by', 'IN'), ('Jennie', 'NNP'), ('Skerl', 'NNP'), ('.', '.')]
# 25th Anniversary ed.
#     [('25th', 'JJ'), ('Anniversary', 'NNP'), ('ed', 'NN'), ('.', '.')]
# ©1959.
#     [('©1959', 'NN'), ('.', '.')]
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# Includes 500 numbered, signed copies issued without dustjacket in slipcase.
#     [('Includes', 'NNS'), ('500', 'CD'), ('numbered', 'JJ'), (',', ','), ('signed', 'JJ'), ('copies', 'NNS'), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), ('in', 'IN'), ('slipcase', 'NN'), ('.', '.')]
# A2k
# ©1982.
#     [('©1982', 'NN'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# Reprinted in 1990 and 1992 (with different cover and titled: Naked Lunch).
#     [('Reprinted', 'VBN'), ('in', 'IN'), ('1990', 'CD'), ('and', 'CC'), ('1992', 'CD'), ('(', '('), ('with', 'IN'), ('different', 'JJ'), ('cover', 'NN'), ('and', 'CC'), ('titled', 'VBN'), (':', ':'), ('Naked', 'NNP'), ('Lunch', 'NNP'), (')', ')'), ('.', '.')]
# A2l
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# A2m
# 1st Evergreen ed.
#     [('1st', 'CD'), ('Evergreen', 'NNP'), ('ed', 'NN'), ('.', '.')]
# ©1990.
#     [('©1990', 'NN'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# Includes, at the beginning as “Introduction,” “Deposition: Testimony Concerning a Sickness” [originally published in Evergreen Review, Vol.
#     [('Includes', 'NNS'), (',', ','), ('at', 'IN'), ('the', 'DT'), ('beginning', 'NN'), ('as', 'IN'), ('“', 'JJ'), ('Introduction', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('Deposition', 'NNP'), (':', ':'), ('Testimony', 'NN'), ('Concerning', 'VBG'), ('a', 'DT'), ('Sickness', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('Evergreen', 'NNP'), ('Review', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 4, No.
#     [('4', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 11 (January-February 1960); see Section C below]” and “Afterthoughts on a Deposition” (October 1991); and, at the end as “Appendix,” “Letter from a Master Addict to Dangerous Drugs” [originally published in The British Journal of Addiction, Vol.
#     [('11', 'CD'), ('(', '('), ('January-February', 'JJ'), ('1960', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('”', 'NNP'), ('and', 'CC'), ('“', 'NNP'), ('Afterthoughts', 'NNP'), ('on', 'IN'), ('a', 'DT'), ('Deposition', 'NNP'), ('”', 'NNP'), ('(', '('), ('October', 'NNP'), ('1991', 'CD'), (')', ')'), (';', ':'), ('and', 'CC'), (',', ','), ('at', 'IN'), ('the', 'DT'), ('end', 'NN'), ('as', 'IN'), ('“', 'JJ'), ('Appendix', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('Letter', 'NNP'), ('from', 'IN'), ('a', 'DT'), ('Master', 'NNP'), ('Addict', 'NNP'), ('to', 'TO'), ('Dangerous', 'NNP'), ('Drugs', 'NNP'), ('”', 'NNP'), ('[', 'NNP'), ('originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('The', 'DT'), ('British', 'JJ'), ('Journal', 'NNP'), ('of', 'IN'), ('Addiction', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.')]
# 53, No.
#     [('53', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 2 (January 1957); see Section C below].
#     [('2', 'CD'), ('(', '('), ('January', 'NNP'), ('1957', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (']', 'NNP'), ('.', '.')]
# Reprinted several times, including in 2000 with an Introduction by Terry Southern.
#     [('Reprinted', 'VBN'), ('several', 'JJ'), ('times', 'NNS'), (',', ','), ('including', 'VBG'), ('in', 'IN'), ('2000', 'CD'), ('with', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('Terry', 'NNP'), ('Southern', 'NNP'), ('.', '.')]
# A2n
# Introduction by J.G.
#     [('Introduction', 'NN'), ('by', 'IN'), ('J.G', 'NNP'), ('.', '.')]
# Ballard.
#     [('Ballard', 'NNP'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A2o
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# Printed separately and as part of nine-volume box set titled The Swinging Sixties.
#     [('Printed', 'VBN'), ('separately', 'RB'), ('and', 'CC'), ('as', 'IN'), ('part', 'NN'), ('of', 'IN'), ('nine-volume', 'JJ'), ('box', 'NN'), ('set', 'VBN'), ('titled', 'VBD'), ('The', 'DT'), ('Swinging', 'NNP'), ('Sixties', 'NNPS'), ('.', '.')]
# A2p
# Edited by James Grauerholz and Barry Miles.
#     [('Edited', 'VBN'), ('by', 'IN'), ('James', 'NNP'), ('Grauerholz', 'NNP'), ('and', 'CC'), ('Barry', 'NNP'), ('Miles', 'NNP'), ('.', '.')]
# 1st ed.
#     [('1st', 'CD'), ('ed', 'NN'), ('.', '.')]
# ©2001.
#     [('©2001', 'NN'), ('.', '.')]
# Hardbound in dustjacket, and softbound.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('and', 'CC'), ('softbound', 'NN'), ('.', '.')]
# “... corrects numerous textual errors accumulated over the years.
#     [('“', 'NN'), ('...', ':'), ('corrects', 'VBZ'), ('numerous', 'JJ'), ('textual', 'JJ'), ('errors', 'NNS'), ('accumulated', 'VBD'), ('over', 'IN'), ('the', 'DT'), ('years', 'NNS'), ('.', '.')]
# ... also incorporates Burroughs’s own notes on the text, all the accompanying essays that he added to later editions [i.e., to editions later than the first, but preceding this edition], and ... an appendix of abundant, newly discovered material and alternate drafts from the original manuscript ...”—Dustjacket.
#     [('...', ':'), ('also', 'RB'), ('incorporates', 'VBZ'), ('Burroughs', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('own', 'JJ'), ('notes', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('text', 'NN'), (',', ','), ('all', 'PDT'), ('the', 'DT'), ('accompanying', 'VBG'), ('essays', 'NNS'), ('that', 'IN'), ('he', 'PRP'), ('added', 'VBD'), ('to', 'TO'), ('later', 'VB'), ('editions', 'NNS'), ('[', 'NNP'), ('i.e.', 'NN'), (',', ','), ('to', 'TO'), ('editions', 'NNS'), ('later', 'RB'), ('than', 'IN'), ('the', 'DT'), ('first', 'JJ'), (',', ','), ('but', 'CC'), ('preceding', 'VBG'), ('this', 'DT'), ('edition', 'NN'), (']', 'NN'), (',', ','), ('and', 'CC'), ('...', ':'), ('an', 'DT'), ('appendix', 'NN'), ('of', 'IN'), ('abundant', 'JJ'), (',', ','), ('newly', 'RB'), ('discovered', 'VBN'), ('material', 'NN'), ('and', 'CC'), ('alternate', 'JJ'), ('drafts', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('manuscript', 'NN'), ('...', ':'), ('”', 'JJ'), ('—Dustjacket', 'NN'), ('.', '.')]
# A2q
# Edited by James Grauerholz and Barry Miles.
#     [('Edited', 'VBN'), ('by', 'IN'), ('James', 'NNP'), ('Grauerholz', 'NNP'), ('and', 'CC'), ('Barry', 'NNP'), ('Miles', 'NNP'), ('.', '.')]
# With an Introduction by John Walsh.
#     [('With', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('John', 'NNP'), ('Walsh', 'NNP'), ('.', '.')]
# (Banned Books; 14) "Includes the accompanying essays that Burroughs added to later editions, but omits the editors' note and the newly discovered material and outtakes which appear in the edition above."
#     [('(', '('), ('Banned', 'VBN'), ('Books', 'NNP'), (';', ':'), ('14', 'CD'), (')', ')'), ('``', '``'), ('Includes', 'VBZ'), ('the', 'DT'), ('accompanying', 'VBG'), ('essays', 'NNS'), ('that', 'WDT'), ('Burroughs', 'NNP'), ('added', 'VBD'), ('to', 'TO'), ('later', 'JJ'), ('editions', 'NNS'), (',', ','), ('but', 'CC'), ('omits', 'VBZ'), ('the', 'DT'), ('editors', 'NNS'), ("'", 'POS'), ('note', 'NN'), ('and', 'CC'), ('the', 'DT'), ('newly', 'RB'), ('discovered', 'VBN'), ('material', 'NN'), ('and', 'CC'), ('outtakes', 'NNS'), ('which', 'WDT'), ('appear', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('edition', 'NN'), ('above', 'IN'), ('.', '.'), ("''", "''")]
# [BeatBooks 59]
#     [('[', 'JJ'), ('BeatBooks', 'NNP'), ('59', 'CD'), (']', 'NN')]
# A2r
# Edited by James Grauerholz and Barry Miles.
#     [('Edited', 'VBN'), ('by', 'IN'), ('James', 'NNP'), ('Grauerholz', 'NNP'), ('and', 'CC'), ('Barry', 'NNP'), ('Miles', 'NNP'), ('.', '.')]
# Afterword by David L. Ulin.
#     [('Afterword', 'NNP'), ('by', 'IN'), ('David', 'NNP'), ('L.', 'NNP'), ('Ulin', 'NNP'), ('.', '.')]
# 50th Anniversary ed.
#     [('50th', 'JJ'), ('Anniversary', 'NNP'), ('ed', 'NN'), ('.', '.')]
# ©2001.
#     [('©2001', 'NN'), ('.', '.')]
# Hardbound, issued without dustjacket .
#     [('Hardbound', 'NNP'), (',', ','), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# Cover emulates colors and design of 1st edition, 1st printing dustjacket; slipcase emulates color of 1st edition cover.
#     [('Cover', 'NNP'), ('emulates', 'VBZ'), ('colors', 'NNS'), ('and', 'CC'), ('design', 'NN'), ('of', 'IN'), ('1st', 'CD'), ('edition', 'NN'), (',', ','), ('1st', 'CD'), ('printing', 'NN'), ('dustjacket', 'NN'), (';', ':'), ('slipcase', 'NN'), ('emulates', 'VBZ'), ('color', 'NN'), ('of', 'IN'), ('1st', 'CD'), ('edition', 'NN'), ('cover', 'NN'), ('.', '.')]
# A3a
# With Brion Gysin.
#     [('With', 'IN'), ('Brion', 'NNP'), ('Gysin', 'NNP'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A4a} “This book was designed and printed by Dave L. Haselwood and James F. McIlroy ...”—Colophon.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A4a', 'NNP'), ('}', ')'), ('“', 'VBZ'), ('This', 'DT'), ('book', 'NN'), ('was', 'VBD'), ('designed', 'VBN'), ('and', 'CC'), ('printed', 'VBN'), ('by', 'IN'), ('Dave', 'NNP'), ('L.', 'NNP'), ('Haselwood', 'NNP'), ('and', 'CC'), ('James', 'NNP'), ('F.', 'NNP'), ('McIlroy', 'NNP'), ('...', ':'), ('”', 'JJ'), ('—Colophon', 'NN'), ('.', '.')]
# Cover calligraphy by Brion Gysin.
#     [('Cover', 'NNP'), ('calligraphy', 'NN'), ('by', 'IN'), ('Brion', 'NNP'), ('Gysin', 'NNP'), ('.', '.')]
# A3b
# 2nd ed.
#     [('2nd', 'CD'), ('ed', 'NN'), ('.', '.')]
# ©1960; distributed by City Lights Books.
#     [('©1960', 'NN'), (';', ':'), ('distributed', 'VBN'), ('by', 'IN'), ('City', 'NNP'), ('Lights', 'NNP'), ('Books', 'NNP'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A4b}  New cover design, with calligraphy by Brion Gysin.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A4b', 'NNP'), ('}', ')'), ('New', 'NNP'), ('cover', 'NN'), ('design', 'NN'), (',', ','), ('with', 'IN'), ('calligraphy', 'NN'), ('by', 'IN'), ('Brion', 'NNP'), ('Gysin', 'NNP'), ('.', '.')]
# A4a
# With Sinclair Beiles, Gregory Corso, and Brion Gysin.
#     [('With', 'IN'), ('Sinclair', 'NNP'), ('Beiles', 'NNP'), (',', ','), ('Gregory', 'NNP'), ('Corso', 'NNP'), (',', ','), ('and', 'CC'), ('Brion', 'NNP'), ('Gysin', 'NNP'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A3a}  “The first collection of cut-ups.” [BeatBooks 65]  “Some [early] copies were issued with a white wraparound band ...” [M&M]  Includes 10 numbered copies (of which only 5 were offered for sale), signed by the publisher and including a manuscript page from each of the four authors.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A3a', 'NNP'), ('}', ')'), ('“', 'VBD'), ('The', 'DT'), ('first', 'JJ'), ('collection', 'NN'), ('of', 'IN'), ('cut-ups.', 'JJ'), ('”', 'NNP'), ('[', 'NNP'), ('BeatBooks', 'NNP'), ('65', 'CD'), (']', 'NNP'), ('“', 'NNP'), ('Some', 'DT'), ('[', 'VBP'), ('early', 'JJ'), (']', 'NN'), ('copies', 'NNS'), ('were', 'VBD'), ('issued', 'VBN'), ('with', 'IN'), ('a', 'DT'), ('white', 'JJ'), ('wraparound', 'NN'), ('band', 'NN'), ('...', ':'), ('”', 'JJ'), ('[', 'NNP'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), (']', 'NNP'), ('\uf0d8', 'NNP'), ('Includes', 'NNP'), ('10', 'CD'), ('numbered', 'JJ'), ('copies', 'NNS'), ('(', '('), ('of', 'IN'), ('which', 'WDT'), ('only', 'RB'), ('5', 'CD'), ('were', 'VBD'), ('offered', 'VBN'), ('for', 'IN'), ('sale', 'NN'), (')', ')'), (',', ','), ('signed', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('publisher', 'NN'), ('and', 'CC'), ('including', 'VBG'), ('a', 'DT'), ('manuscript', 'JJ'), ('page', 'NN'), ('from', 'IN'), ('each', 'DT'), ('of', 'IN'), ('the', 'DT'), ('four', 'CD'), ('authors', 'NNS'), ('.', '.')]
# Not on “fine paper,” as M&M claims.
#     [('Not', 'RB'), ('on', 'IN'), ('“', 'JJ'), ('fine', 'JJ'), ('paper', 'NN'), (',', ','), ('”', 'CC'), ('as', 'IN'), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('claims', 'VBZ'), ('.', '.')]
# [Shoaf 1]
#     [('[', 'JJ'), ('Shoaf', 'NNP'), ('1', 'CD'), (']', 'NN')]
# A4b
# 1st American ed.
#     [('1st', 'CD'), ('American', 'JJ'), ('ed', 'NN'), ('.', '.')]
# ; distributed by City Lights Books.
#     [(';', ':'), ('distributed', 'VBN'), ('by', 'IN'), ('City', 'NNP'), ('Lights', 'NNP'), ('Books', 'NNP'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A3b}
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A3b', 'NNP'), ('}', ')')]
# A5a
# (The Travellers Companion Series, No.
#     [('(', '('), ('The', 'DT'), ('Travellers', 'NNPS'), ('Companion', 'NNP'), ('Series', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 88) Softbound in dustjacket (no hardbound issued).
#     [('88', 'CD'), (')', ')'), ('Softbound', 'NN'), ('in', 'IN'), ('dustjacket', 'NN'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A5a}   First version.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A5a', 'NNP'), ('}', ')'), ('First', 'NNP'), ('version', 'NN'), ('.', '.')]
# Dustjacket reproduces calligraphic drawing by Brion Gysin.
#     [('Dustjacket', 'NNP'), ('reproduces', 'NNS'), ('calligraphic', 'JJ'), ('drawing', 'VBG'), ('by', 'IN'), ('Brion', 'NNP'), ('Gysin', 'NNP'), ('.', '.')]
# All copies of the book were issued exactly the same.
#     [('All', 'DT'), ('copies', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('book', 'NN'), ('were', 'VBD'), ('issued', 'VBN'), ('exactly', 'RB'), ('the', 'DT'), ('same', 'JJ'), ('.', '.')]
# Some copies, however (so-called “second issue”), had a price change (“New Price NF18”) stamped (or added on sticker) on back cover at a later date.
#     [('Some', 'DT'), ('copies', 'NNS'), (',', ','), ('however', 'RB'), ('(', '('), ('so-called', 'JJ'), ('“', 'NNP'), ('second', 'JJ'), ('issue', 'NN'), ('”', 'NNP'), (')', ')'), (',', ','), ('had', 'VBD'), ('a', 'DT'), ('price', 'NN'), ('change', 'NN'), ('(', '('), ('“', 'JJ'), ('New', 'NNP'), ('Price', 'NNP'), ('NF18', 'NNP'), ('”', 'NNP'), (')', ')'), ('stamped', 'VBD'), ('(', '('), ('or', 'CC'), ('added', 'VBN'), ('on', 'IN'), ('sticker', 'NN'), (')', ')'), ('on', 'IN'), ('back', 'JJ'), ('cover', 'NN'), ('at', 'IN'), ('a', 'DT'), ('later', 'JJ'), ('date', 'NN'), ('.', '.')]
# A5b
# Hardbound in dustjacket (no softbound issued).
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('(', '('), ('no', 'DT'), ('softbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A5b} Second version.
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A5b', 'NNP'), ('}', ')'), ('Second', 'NNP'), ('version', 'NN'), ('.', '.')]
# “Burroughs completely rewrote the text for this edition, partly as a response to criticisms  that the first edition had been difficult to read.” [BeatBooks 48]  “This constitutes the revised expanded edition advertised but never published by Olympia [Press].” [Am Here 3]  2nd printing, 1966.
#     [('“', 'JJ'), ('Burroughs', 'NNP'), ('completely', 'RB'), ('rewrote', 'VBP'), ('the', 'DT'), ('text', 'NN'), ('for', 'IN'), ('this', 'DT'), ('edition', 'NN'), (',', ','), ('partly', 'RB'), ('as', 'IN'), ('a', 'DT'), ('response', 'NN'), ('to', 'TO'), ('criticisms', 'VB'), ('that', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('edition', 'NN'), ('had', 'VBD'), ('been', 'VBN'), ('difficult', 'JJ'), ('to', 'TO'), ('read.', 'VB'), ('”', 'NNP'), ('[', 'NNP'), ('BeatBooks', 'NNP'), ('48', 'CD'), (']', 'NNP'), ('“', 'NN'), ('This', 'DT'), ('constitutes', 'VBZ'), ('the', 'DT'), ('revised', 'VBN'), ('expanded', 'JJ'), ('edition', 'NN'), ('advertised', 'VBD'), ('but', 'CC'), ('never', 'RB'), ('published', 'VBN'), ('by', 'IN'), ('Olympia', 'NNP'), ('[', 'NNP'), ('Press', 'NNP'), (']', 'NNP'), ('.', '.'), ('”', 'VB'), ('[', 'JJ'), ('Am', 'NNP'), ('Here', 'RB'), ('3', 'CD'), (']', 'JJ'), ('2nd', 'CD'), ('printing', 'NN'), (',', ','), ('1966', 'CD'), ('.', '.')]
# [BeatBooks 36]
#     [('[', 'JJ'), ('BeatBooks', 'NNP'), ('36', 'CD'), (']', 'NN')]
# A5c
# 1st Evergreen Black Cat ed.
#     [('1st', 'CD'), ('Evergreen', 'JJ'), ('Black', 'NNP'), ('Cat', 'NNP'), ('ed', 'NN'), ('.', '.')]
# (An Evergreen Black Cat Book, BC-131) ©1966.
#     [('(', '('), ('An', 'DT'), ('Evergreen', 'NNP'), ('Black', 'NNP'), ('Cat', 'NNP'), ('Book', 'NNP'), (',', ','), ('BC-131', 'NNP'), (')', ')'), ('©1966', 'NN'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# {M&M A5c}
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A5c', 'NNP'), ('}', ')')]
# A5d
# Rev.
#     [('Rev', 'NNP'), ('.', '.')]
# ed.
#     [('ed', 'NN'), ('.', '.')]
# Hardbound in dustjacket, and softbound.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('and', 'CC'), ('softbound', 'NN'), ('.', '.')]
# {M&M A5d and A5e} Third version: “... this final, definitive edition has been considerably revised by the author from the two earlier versions.”—Dustjacket (rear).
#     [('{', '('), ('M', 'NNP'), ('&', 'CC'), ('M', 'NNP'), ('A5d', 'NNP'), ('and', 'CC'), ('A5e', 'NNP'), ('}', ')'), ('Third', 'NNP'), ('version', 'NN'), (':', ':'), ('“', 'NN'), ('...', ':'), ('this', 'DT'), ('final', 'JJ'), (',', ','), ('definitive', 'JJ'), ('edition', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('considerably', 'RB'), ('revised', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('author', 'NN'), ('from', 'IN'), ('the', 'DT'), ('two', 'CD'), ('earlier', 'JJR'), ('versions.', 'NN'), ('”', 'NN'), ('—Dustjacket', 'NN'), ('(', '('), ('rear', 'JJ'), (')', ')'), ('.', '.')]
# A5e
# Softbound (no hardbound issued).
# ...
#     [('46', 'CD'), (')', ')'), ('Limited', 'VBD'), ('to', 'TO'), ('250', 'CD'), ('copies', 'NNS'), (',', ','), ('including', 'VBG'), ('49', 'CD'), ('numbered', 'JJ'), ('and', 'CC'), ('26', 'CD'), ('lettered', 'JJ'), ('copies', 'NNS'), ('signed', 'VBN'), ('by', 'IN'), ('Burroughs', 'NNP'), ('.', '.')]
# Features photos of Burroughs by Ginsberg and Burroughs’ text about Kerouac, also published separately as a broadside titled Remembering Jack Kerouac, below.
#     [('Features', 'NNS'), ('photos', 'NNS'), ('of', 'IN'), ('Burroughs', 'NNP'), ('by', 'IN'), ('Ginsberg', 'NNP'), ('and', 'CC'), ('Burroughs', 'NNP'), ('’', 'NNP'), ('text', 'NN'), ('about', 'IN'), ('Kerouac', 'NNP'), (',', ','), ('also', 'RB'), ('published', 'VBN'), ('separately', 'RB'), ('as', 'IN'), ('a', 'DT'), ('broadside', 'NN'), ('titled', 'VBN'), ('Remembering', 'NNP'), ('Jack', 'NNP'), ('Kerouac', 'NNP'), (',', ','), ('below', 'IN'), ('.', '.')]
# A70a
# (Heaven Poster Series; No.
#     [('(', '('), ('Heaven', 'NNP'), ('Poster', 'NNP'), ('Series', 'NNP'), (';', ':'), ('No', 'NNP'), ('.', '.')]
# 10) Broadside.
#     [('10', 'CD'), (')', ')'), ('Broadside', 'NNP'), ('.', '.')]
# Limited to 500 copies signed by Burroughs, 49 of which are numbered and 26 of which are lettered.
#     [('Limited', 'VBN'), ('to', 'TO'), ('500', 'CD'), ('copies', 'NNS'), ('signed', 'VBN'), ('by', 'IN'), ('Burroughs', 'NNP'), (',', ','), ('49', 'CD'), ('of', 'IN'), ('which', 'WDT'), ('are', 'VBP'), ('numbered', 'VBN'), ('and', 'CC'), ('26', 'CD'), ('of', 'IN'), ('which', 'WDT'), ('are', 'VBP'), ('lettered', 'VBN'), ('.', '.')]
# A71a
# Translated into French by Mary Beach and Claude Pélieu.
#     [('Translated', 'VBN'), ('into', 'IN'), ('French', 'JJ'), ('by', 'IN'), ('Mary', 'NNP'), ('Beach', 'NNP'), ('and', 'CC'), ('Claude', 'NNP'), ('Pélieu', 'NNP'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# No equivalent English-language edition.
#     [('No', 'DT'), ('equivalent', 'JJ'), ('English-language', 'JJ'), ('edition', 'NN'), ('.', '.')]
# A72a
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A73a
# Hardbound in dustjacket, and softbound.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('and', 'CC'), ('softbound', 'NN'), ('.', '.')]
# “cover art collage derived from [3] paintings by William S. Burroughs” —Dustjacket.
#     [('“', 'NN'), ('cover', 'WRB'), ('art', 'NN'), ('collage', 'NN'), ('derived', 'VBN'), ('from', 'IN'), ('[', 'JJ'), ('3', 'CD'), (']', 'JJ'), ('paintings', 'NNS'), ('by', 'IN'), ('William', 'NNP'), ('S.', 'NNP'), ('Burroughs', 'NNP'), ('”', 'NNP'), ('—Dustjacket', 'NNP'), ('.', '.')]
# A73b
# 1st British ed.
#     [('1st', 'CD'), ('British', 'JJ'), ('ed', 'NN'), ('.', '.')]
# Hardbound in dustjacket, and softbound.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('and', 'CC'), ('softbound', 'NN'), ('.', '.')]
# A73c
# ©1995.
#     [('©1995', 'NN'), ('.', '.')]
# Softbound (no hardbound issued).
#     [('Softbound', 'NNP'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# A74a
# Broadside.
#     [('Broadside', 'NNP'), ('.', '.')]
# Silkscreen print (from the authors handwriting) and colophon page enclosed in a printed folder, which is, in turn, enclosed in a printed envelope.
#     [('Silkscreen', 'JJ'), ('print', 'NN'), ('(', '('), ('from', 'IN'), ('the', 'DT'), ('authors', 'NNS'), ('handwriting', 'VBG'), (')', ')'), ('and', 'CC'), ('colophon', 'JJ'), ('page', 'NN'), ('enclosed', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('printed', 'JJ'), ('folder', 'NN'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), (',', ','), ('in', 'IN'), ('turn', 'NN'), (',', ','), ('enclosed', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('printed', 'JJ'), ('envelope', 'NN'), ('.', '.')]
# Limited to 60 numbered copies signed by Burroughs.
#     [('Limited', 'VBN'), ('to', 'TO'), ('60', 'CD'), ('numbered', 'JJ'), ('copies', 'NNS'), ('signed', 'VBN'), ('by', 'IN'), ('Burroughs', 'NNP'), ('.', '.')]
# “The lyrics for the song ‘Pantopon Rose,’ written in January 1995, are based on a real character ... She appears in several of Burroughs’ books, including The Naked Lunch ...”
#     [('“', 'IN'), ('The', 'DT'), ('lyrics', 'NNS'), ('for', 'IN'), ('the', 'DT'), ('song', 'NN'), ('‘', 'NNP'), ('Pantopon', 'NNP'), ('Rose', 'NNP'), (',', ','), ('’', 'NNP'), ('written', 'VBN'), ('in', 'IN'), ('January', 'NNP'), ('1995', 'CD'), (',', ','), ('are', 'VBP'), ('based', 'VBN'), ('on', 'IN'), ('a', 'DT'), ('real', 'JJ'), ('character', 'NN'), ('...', ':'), ('She', 'PRP'), ('appears', 'VBZ'), ('in', 'IN'), ('several', 'JJ'), ('of', 'IN'), ('Burroughs', 'NNP'), ('’', 'NNP'), ('books', 'NNS'), (',', ','), ('including', 'VBG'), ('The', 'DT'), ('Naked', 'NNP'), ('Lunch', 'NN'), ('...', ':'), ('”', 'NN')]
# A75a
# Broadside.
#     [('Broadside', 'NNP'), ('.', '.')]
# Limited to 200 copies.
#     [('Limited', 'VBN'), ('to', 'TO'), ('200', 'CD'), ('copies', 'NNS'), ('.', '.')]
# A76a
# Edited by James Grauerholz and Ira Silverberg, with an Introduction by Ann Douglas.
#     [('Edited', 'VBN'), ('by', 'IN'), ('James', 'NNP'), ('Grauerholz', 'NNP'), ('and', 'CC'), ('Ira', 'NNP'), ('Silverberg', 'NNP'), (',', ','), ('with', 'IN'), ('an', 'DT'), ('Introduction', 'NN'), ('by', 'IN'), ('Ann', 'NNP'), ('Douglas', 'NNP'), ('.', '.')]
# A.
#     [('A', 'DT'), ('.', '.')]
# 1st ed.
#     [('1st', 'CD'), ('ed', 'NN'), ('.', '.')]
# , 1998.
#     [(',', ','), ('1998', 'CD'), ('.', '.')]
# Hardbound in dustjacket, issued with compact disc bound in rear.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), (',', ','), ('issued', 'VBN'), ('with', 'IN'), ('compact', 'JJ'), ('disc', 'NN'), ('bound', 'NN'), ('in', 'IN'), ('rear', 'NN'), ('.', '.')]
# Includes a chapter from Burroughs’ previously unpublished novel written collaboratively with Jack Kerouac, And the Hippos Were Boiled in Their Tanks, below.
#     [('Includes', 'VBZ'), ('a', 'DT'), ('chapter', 'NN'), ('from', 'IN'), ('Burroughs', 'NNP'), ('’', 'NNP'), ('previously', 'RB'), ('unpublished', 'VBD'), ('novel', 'JJ'), ('written', 'VBN'), ('collaboratively', 'RB'), ('with', 'IN'), ('Jack', 'NNP'), ('Kerouac', 'NNP'), (',', ','), ('And', 'CC'), ('the', 'DT'), ('Hippos', 'NNP'), ('Were', 'NNP'), ('Boiled', 'VBN'), ('in', 'IN'), ('Their', 'NNP'), ('Tanks', 'NNP'), (',', ','), ('below', 'IN'), ('.', '.')]
# Compact disc: Selections from The Best of William Burroughs from Giorno Poetry Systems (also issued separately; see Section E below).
#     [('Compact', 'JJ'), ('disc', 'NN'), (':', ':'), ('Selections', 'NNS'), ('from', 'IN'), ('The', 'DT'), ('Best', 'NNP'), ('of', 'IN'), ('William', 'NNP'), ('Burroughs', 'NNP'), ('from', 'IN'), ('Giorno', 'NNP'), ('Poetry', 'NNP'), ('Systems', 'NNP'), ('(', '('), ('also', 'RB'), ('issued', 'VBN'), ('separately', 'RB'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('E', 'NNP'), ('below', 'IN'), (')', ')'), ('.', '.')]
# A76b
# (Modern Classic) Softbound.
#     [('(', '('), ('Modern', 'NNP'), ('Classic', 'NNP'), (')', ')'), ('Softbound', 'NNP'), ('.', '.')]
# A76c
# 1st paperback ed.
#     [('1st', 'CD'), ('paperback', 'NN'), ('ed', 'NN'), ('.', '.')]
# ©1998.
#     [('©1998', 'NN'), ('.', '.')]
# Softbound.
#     [('Softbound', 'NN'), ('.', '.')]
# A77a
# Softbound; handbound (no hardbound issued).
#     [('Softbound', 'NNP'), (';', ':'), ('handbound', 'NN'), ('(', '('), ('no', 'DT'), ('hardbound', 'NN'), ('issued', 'VBD'), (')', ')'), ('.', '.')]
# Contains three original b&w photographs, “... two of which are previously unpublished ... taken by an unknown person who accompanied Burroughs on his expedition through the Amazon.”—Colophon.
#     [('Contains', 'NNS'), ('three', 'CD'), ('original', 'JJ'), ('b', 'NN'), ('&', 'CC'), ('w', 'NN'), ('photographs', 'NN'), (',', ','), ('“', "''"), ('...', ':'), ('two', 'CD'), ('of', 'IN'), ('which', 'WDT'), ('are', 'VBP'), ('previously', 'RB'), ('unpublished', 'JJ'), ('...', ':'), ('taken', 'VBN'), ('by', 'IN'), ('an', 'DT'), ('unknown', 'JJ'), ('person', 'NN'), ('who', 'WP'), ('accompanied', 'VBD'), ('Burroughs', 'NNP'), ('on', 'IN'), ('his', 'PRP$'), ('expedition', 'NN'), ('through', 'IN'), ('the', 'DT'), ('Amazon.', 'NNP'), ('”', 'NNP'), ('—Colophon', 'NNP'), ('.', '.')]
# “This edition consists of 26 lettered copies.
#     [('“', 'NN'), ('This', 'DT'), ('edition', 'NN'), ('consists', 'VBZ'), ('of', 'IN'), ('26', 'CD'), ('lettered', 'JJ'), ('copies', 'NNS'), ('.', '.')]
# The photographs were reproduced from the original negatives and are the only prints that will be made from these negatives.”—Colophon.
#     [('The', 'DT'), ('photographs', 'NN'), ('were', 'VBD'), ('reproduced', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('negatives', 'NNS'), ('and', 'CC'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('prints', 'NNS'), ('that', 'WDT'), ('will', 'MD'), ('be', 'VB'), ('made', 'VBN'), ('from', 'IN'), ('these', 'DT'), ('negatives.', 'JJ'), ('”', 'NN'), ('—Colophon', 'NN'), ('.', '.')]
# A78a
# Staplebound.
#     [('Staplebound', 'NN'), ('.', '.')]
# Originally published in Univers, No.
#     [('Originally', 'RB'), ('published', 'VBN'), ('in', 'IN'), ('Univers', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 10 (1977).
#     [('10', 'CD'), ('(', '('), ('1977', 'CD'), (')', ')'), ('.', '.')]
# Translation and adaptation by Mary Beach of “To Talk for Joe” (published in Transatlantic Review,  No.
#     [('Translation', 'NN'), ('and', 'CC'), ('adaptation', 'NN'), ('by', 'IN'), ('Mary', 'NNP'), ('Beach', 'NNP'), ('of', 'IN'), ('“', 'NNP'), ('To', 'TO'), ('Talk', 'VB'), ('for', 'IN'), ('Joe', 'NNP'), ('”', 'NNP'), ('(', '('), ('published', 'VBN'), ('in', 'IN'), ('Transatlantic', 'NNP'), ('Review', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 60 (June 1977); see Section C below).
#     [('60', 'CD'), ('(', '('), ('June', 'NNP'), ('1977', 'CD'), (')', ')'), (';', ':'), ('see', 'VB'), ('Section', 'NNP'), ('C', 'NNP'), ('below', 'IN'), (')', ')'), ('.', '.')]
# No equivalent English-language edition.
#     [('No', 'DT'), ('equivalent', 'JJ'), ('English-language', 'JJ'), ('edition', 'NN'), ('.', '.')]
# A79a
# (FreeThought Flyer, No.
#     [('(', '('), ('FreeThought', 'NNP'), ('Flyer', 'NNP'), (',', ','), ('No', 'NNP'), ('.', '.')]
# 16) Staplebound.
#     [('16', 'CD'), (')', ')'), ('Staplebound', 'NN'), ('.', '.')]
# Cover photo of Burroughs by Michael Montfort.
#     [('Cover', 'NNP'), ('photo', 'NN'), ('of', 'IN'), ('Burroughs', 'NNP'), ('by', 'IN'), ('Michael', 'NNP'), ('Montfort', 'NNP'), ('.', '.')]
# Limited to 250 numbered and 26 lettered copies signed by the photographer.
#     [('Limited', 'VBN'), ('to', 'TO'), ('250', 'CD'), ('numbered', 'JJ'), ('and', 'CC'), ('26', 'CD'), ('lettered', 'JJ'), ('copies', 'NNS'), ('signed', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('photographer', 'NN'), ('.', '.')]
# Includes five copies stamped “publisher’s copy.” [Shoaf 2]
#     [('Includes', 'NNP'), ('five', 'CD'), ('copies', 'NNS'), ('stamped', 'VBD'), ('“', 'VB'), ('publisher', 'NN'), ('’', 'NNP'), ('s', 'NN'), ('copy.', 'NN'), ('”', 'NNP'), ('[', 'NNP'), ('Shoaf', 'NNP'), ('2', 'CD'), (']', 'NN')]
# A80a
# General editors, Geoffrey D. Smith and John M. Bennett; volume editor, Oliver Harris.
#     [('General', 'JJ'), ('editors', 'NNS'), (',', ','), ('Geoffrey', 'NNP'), ('D.', 'NNP'), ('Smith', 'NNP'), ('and', 'CC'), ('John', 'NNP'), ('M.', 'NNP'), ('Bennett', 'NNP'), (';', ':'), ('volume', 'NN'), ('editor', 'NN'), (',', ','), ('Oliver', 'NNP'), ('Harris', 'NNP'), ('.', '.')]
# Hardbound (issued without dustjacket).
#     [('Hardbound', 'NNP'), ('(', '('), ('issued', 'VBN'), ('without', 'IN'), ('dustjacket', 'NN'), (')', ')'), ('.', '.')]
# "... written by William Burroughs in Latin America during July and August 1953 ..." - Introduction.
#     [('``', '``'), ('...', ':'), ('written', 'VBN'), ('by', 'IN'), ('William', 'NNP'), ('Burroughs', 'NNP'), ('in', 'IN'), ('Latin', 'NNP'), ('America', 'NNP'), ('during', 'IN'), ('July', 'NNP'), ('and', 'CC'), ('August', 'NNP'), ('1953', 'CD'), ('...', ':'), ("''", "''"), ('-', ':'), ('Introduction', 'NN'), ('.', '.')]
# A81a
# With Jack Kerouac.
#     [('With', 'IN'), ('Jack', 'NNP'), ('Kerouac', 'NNP'), ('.', '.')]
# 1st ed.
#     [('1st', 'CD'), ('ed', 'NN'), ('.', '.')]
# Hardbound in dustjacket.
#     [('Hardbound', 'NNP'), ('in', 'IN'), ('dustjacket', 'NN'), ('.', '.')]
# Written by the authors in 1945 as a fictionalized account of Lucien Carr’s relationship with, and eventual murder of, David Kammerer.
#     [('Written', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('authors', 'NNS'), ('in', 'IN'), ('1945', 'CD'), ('as', 'IN'), ('a', 'DT'), ('fictionalized', 'JJ'), ('account', 'NN'), ('of', 'IN'), ('Lucien', 'NNP'), ('Carr', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('relationship', 'NN'), ('with', 'IN'), (',', ','), ('and', 'CC'), ('eventual', 'JJ'), ('murder', 'NN'), ('of', 'IN'), (',', ','), ('David', 'NNP'), ('Kammerer', 'NNP'), ('.', '.')]
# “Will Dennison chapters written by William Lee, Mike Ryko chapters by John Kerouac.”—p.
#     [('“', 'NN'), ('Will', 'NNP'), ('Dennison', 'NNP'), ('chapters', 'NNS'), ('written', 'VBN'), ('by', 'IN'), ('William', 'NNP'), ('Lee', 'NNP'), (',', ','), ('Mike', 'NNP'), ('Ryko', 'NNP'), ('chapters', 'NNS'), ('by', 'IN'), ('John', 'NNP'), ('Kerouac.', 'NNP'), ('”', 'NNP'), ('—p', 'NNP'), ('.', '.')]
# [1].
#     [('[', 'RB'), ('1', 'CD'), (']', 'NNS'), ('.', '.')]
# A82a
# Alex Wermer-Colan, ed.
#     [('Alex', 'NNP'), ('Wermer-Colan', 'NNP'), (',', ','), ('ed', 'NN'), ('.', '.')]
# (Lost and Found: The CUNY Poetics Document Initiative; Ser.
#     [('(', '('), ('Lost', 'VBN'), ('and', 'CC'), ('Found', 'VBN'), (':', ':'), ('The', 'DT'), ('CUNY', 'NNP'), ('Poetics', 'NNPS'), ('Document', 'NNP'), ('Initiative', 'NNP'), (';', ':'), ('Ser', 'NNP'), ('.', '.')]
# 5, No.
#     [('5', 'CD'), (',', ','), ('No', 'DT'), ('.', '.')]
# 2) Staplebound.
#     [('2', 'CD'), (')', ')'), ('Staplebound', 'NN'), ('.', '.')]
# “Various cut-ups by William S. Burroughs courtesy of Ohio State University’s Rare Books & Manuscripts Library and the New York Public Library’s Henry W. and Albert A. Berg Collection of English and American Literature ...”—T.p.
#     [('“', 'RB'), ('Various', 'JJ'), ('cut-ups', 'NNS'), ('by', 'IN'), ('William', 'NNP'), ('S.', 'NNP'), ('Burroughs', 'NNP'), ('courtesy', 'NN'), ('of', 'IN'), ('Ohio', 'NNP'), ('State', 'NNP'), ('University', 'NNP'), ('’', 'NNP'), ('s', 'PRP'), ('Rare', 'NNP'), ('Books', 'NNP'), ('&', 'CC'), ('Manuscripts', 'NNP'), ('Library', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('New', 'NNP'), ('York', 'NNP'), ('Public', 'NNP'), ('Library', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('Henry', 'NNP'), ('W.', 'NNP'), ('and', 'CC'), ('Albert', 'NNP'), ('A.', 'NNP'), ('Berg', 'NNP'), ('Collection', 'NNP'), ('of', 'IN'), ('English', 'NNP'), ('and', 'CC'), ('American', 'JJ'), ('Literature', 'NNP'), ('...', ':'), ('”', 'JJ'), ('—T.p', 'NN'), ('.', '.')]
# verso.
#     [('verso', 'NN'), ('.', '.')]
# 1.
#     [('1', 'CD'), ('.', '.')]
# [Promotional Postcard].
#     [('[', 'JJ'), ('Promotional', 'NNP'), ('Postcard', 'NNP'), (']', 'NNP'), ('.', '.')]
# [New York: The Center for the Humanities, The Graduate Center, The City University of New York, 2015.]
#     [('[', 'JJ'), ('New', 'NNP'), ('York', 'NNP'), (':', ':'), ('The', 'DT'), ('Center', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('Humanities', 'NNP'), (',', ','), ('The', 'DT'), ('Graduate', 'NNP'), ('Center', 'NNP'), (',', ','), ('The', 'DT'), ('City', 'NNP'), ('University', 'NNP'), ('of', 'IN'), ('New', 'NNP'), ('York', 'NNP'), (',', ','), ('2015', 'CD'), ('.', '.'), (']', 'VB')]
# On recto: “William S. Burroughs and Kathy Acker at Cold City Gallery in 1989.” (B&W photo by Byron James Bignell.)
#     [('On', 'IN'), ('recto', 'NN'), (':', ':'), ('“', 'JJ'), ('William', 'NNP'), ('S.', 'NNP'), ('Burroughs', 'NNP'), ('and', 'CC'), ('Kathy', 'NNP'), ('Acker', 'NNP'), ('at', 'IN'), ('Cold', 'NNP'), ('City', 'NNP'), ('Gallery', 'NNP'), ('in', 'IN'), ('1989.', 'CD'), ('”', 'NN'), ('(', '('), ('B', 'NNP'), ('&', 'CC'), ('W', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Byron', 'NNP'), ('James', 'NNP'), ('Bignell', 'NNP'), ('.', '.'), (')', ')')]

# %% [markdown]
# ## Generate BIBFRAME Turtle files

# %% [markdown]
# ### Initialize namespaces

# %%
abri = rdflib.Namespace("https://w3id.org/anything-but-routine/4.0/instance/")
abrw = rdflib.Namespace("https://w3id.org/anything-but-routine/4.0/work/")
bf = rdflib.Namespace("http://id.loc.gov/ontologies/bibframe/")
arm = rdflib.Namespace("https://w3id.org/arm/core/ontology/0.1/")

# %% [markdown]
# ### Define function to initialize graphs

# %%
def initialize_abr_graph():
    g = rdflib.Graph()
    g.bind("abri", "https://w3id.org/anything-but-routine/4.0/instance/")
    g.bind("abrw", "https://w3id.org/anything-but-routine/4.0/work/")
    g.bind("bf", "http://id.loc.gov/ontologies/bibframe/")
    g.bind("arm", "https://w3id.org/arm/core/ontology/0.1/")
    return g

# %% [markdown]
# ### Generate instances

# %%
# %%time
instances = df.where((pd.notnull(df)), None).to_dict('records')
work_to_instance_map = collections.defaultdict(list)

for i in instances:
    g = initialize_abr_graph()
    name = i['Schottlaender']
    work_to_instance_map[i['work']].append(name)
    id = abri[name]
    g.add((id, RDF.type, bf.Instance))
    g.add((id, RDFS.label, Literal(i['workTitle'])))
    g.add((id, bf.instanceOf, abrw[i['work']]))
    # bf.contributor
    wsb = BNode()
    g.add((id, bf.contributor, wsb))
    g.add((wsb, RDF.type, bf.Agent))
    g.add((wsb, RDF.type, bf.Person))
    g.add((wsb, bf.role, Literal("author")))
    g.add((wsb, RDFS.label, Literal("William S. Burroughs")))
    # bf:title
    title = BNode()
    g.add((id, bf.title, title))
    g.add((title, RDF.type, bf.Title))
    g.add((title, RDFS.label, Literal(i['instanceTitle'])))
    # bf:identifiedBy
    schottlaender_id = BNode()
    g.add((id, bf.identifiedBy, schottlaender_id))
    g.add((schottlaender_id, RDF.type, bf.Identifier))
    g.add((schottlaender_id, bf.source, Literal("Schottlaender v4.0")))
    g.add((schottlaender_id, RDF.value, Literal(name)))
    m_n_m = i['MaynardAndMiles']
    if m_n_m:
        m_n_m_id = BNode()
        g.add((id, bf.identifiedBy, m_n_m_id))
        g.add((m_n_m_id, RDF.type, bf.Identifier))
        g.add((m_n_m_id, bf.source, Literal("Maynard & Miles")))
        g.add((m_n_m_id, RDF.value, Literal(m_n_m)))
    # bf:note
    notes = i['notes']
    if notes:
        notes_text = nltk.sent_tokenize(notes)
        for sentence in notes_text:
            note = BNode()
            g.add((id, bf.note, note))
            g.add((note, RDF.type, bf.Note))
            g.add((note, RDF.value, Literal(sentence)))
            # Contributors extracted from note
            tokenized = nltk.word_tokenize(sentence)
            tagged = nltk.pos_tag(tokenized)
            namedEnt = nltk.ne_chunk(tagged)
            for t in namedEnt.subtrees():
                if t.label() == 'PERSON':
                    person_tokens = [ c[0] for c in t ]
                    person_name = ' '.join(person_tokens)
                    person = BNode()
                    g.add((id, bf.contributor, person))
                    g.add((person, RDF.type, bf.Agent))
                    g.add((person, RDF.type, bf.Person)) 
                    g.add((person, bf.role, Literal("contributor")))
                    g.add((person, RDFS.label, Literal(person_name)))
    # bf:provisionActivity
    publisher = i['publisher']
    date = i['date']
    place = i['place']
    if publisher and date and place:
        pa_lit = BNode()
        g.add((id, bf.provisionActivity, pa_lit))
        g.add((pa_lit, RDF.type, bf.ProvisionActivity))
        g.add((pa_lit, RDF.type, bf.Publication))
        g.add((pa_lit, bf.agent, Literal(publisher)))
        g.add((pa_lit, bf.date, Literal(date)))
        g.add((pa_lit, bf.place, Literal(place)))
    # bf:copyrightDate
    copyrightDate = i['copyrightDate']
    if copyrightDate:
        g.add((id, bf.copyrightDate, Literal(copyrightDate)))
    g.serialize(f"ttl/instance/{name}.ttl", format='turtle')
# Out:
# CPU times: user 17.9 s, sys: 1.01 s, total: 18.9 s
# Wall time: 25.4 s

# %% [markdown]
# ### Generate works

# %%
works = pd.DataFrame(df[['workTitle', 'work']]).drop_duplicates().to_dict('records')

for work in works:
    g = initialize_abr_graph()
    name = work['work']
    id = abrw[name]
    g.add((id, RDF.type, bf.Work))
    g.add((id, RDF.type, bf.Text))
    g.add((id, RDFS.label, Literal(work['workTitle'])))
    wsb = BNode()
    g.add((id, bf.contributor, wsb))
    g.add((wsb, RDF.type, bf.Agent))
    g.add((wsb, RDF.type, bf.Person)) 
    g.add((wsb, RDFS.label, Literal("William S. Burroughs")))
    for inst in work_to_instance_map[name]:
        g.add((id, bf.hasInstance, abri[inst]))
    g.serialize(f"ttl/work/{name}.ttl", format='turtle')
