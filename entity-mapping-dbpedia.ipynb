# %%
import rdflib, mimeparse, requests
from rdflib import URIRef
from rdflib.namespace import RDF, RDFS, VOID

# %%
abr = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/")
abrc = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/classification/")
abri = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/instance/")
abrw = rdflib.Namespace("https://wsburroughs.link/anything-but-routine/4.0/work/")
bf = rdflib.Namespace("http://id.loc.gov/ontologies/bibframe/")
arm = rdflib.Namespace("https://w3id.org/arm/core/ontology/0.1/")

# %%
def initialize_abr_graph():
    g = rdflib.Graph()
    g.bind("abr", "https://wsburroughs.link/anything-but-routine/")
    g.bind("abrc", "https://wsburroughs.link/anything-but-routine/4.0/classification/")
    g.bind("abri", "https://wsburroughs.link/anything-but-routine/4.0/instance/")
    g.bind("abrw", "https://wsburroughs.link/anything-but-routine/4.0/work/")
    g.bind("bf", "http://id.loc.gov/ontologies/bibframe/")
    g.bind("arm", "https://w3id.org/arm/core/ontology/0.1/")
    return g

# %%
headers = { 'Accept': 'text/turtle, application/rdf+xml' }

# %%
def parse_response(graph, res):
    (media_type, media_subtype, params) = mimeparse.parse_mime_type(res.headers.get('content-type'))
    graph.parse(data=res.text, format=f'{media_type}/{media_subtype}')

# %%
def load_void_resources(graph, uri):
    res = requests.get(uri, headers=headers)
    if res.status_code  == requests.codes.ok:
        parse_response(graph, res)
        dump_file = graph.value(URIRef(uri), VOID.dataDump)
        print(dump_file)
        if dump_file:
            res = requests.get(dump_file, headers=headers)
            if res.status_code  == requests.codes.ok:
                parse_response(graph, res)
        else:
            for o in graph.objects(URIRef(uri), VOID.rootResource):
                find_and_follow(graph, o)

# %%
def find_and_follow(graph, uri, level=3):
    if not uri in graph.subjects():
        res = requests.get(uri, headers=headers)
        if res.status_code  == requests.codes.ok:
            parse_response(graph, res)
            if level > 0:
                for o in graph.objects(uri, None):
                    if type(o) == rdflib.term.URIRef:
                        find_and_follow(graph, o, level=level-1)

# %%
# %%time
graph = initialize_abr_graph()
load_void_resources(graph, 'https://wsburroughs.link/anything-but-routine/')
# Out:
# https://wsburroughs.link/anything-but-routine/dump
# CPU times: user 4.1 s, sys: 97.8 ms, total: 4.2 s
# Wall time: 17.4 s

# %%
n_entities = len([ cl for cl in graph.subjects(RDF.type, bf.Classification) ])
n_entities += len([ w for w in graph.subjects(RDF.type, bf.Work) ])
n_entities += len([ i for i in graph.subjects(RDF.type, bf.Instance) ])

n_entities
# Out:
# 324

# %%
len([ w for w in graph.subjects(RDF.type, bf.Work) ])
# Out:
# 85

# %%
len([ i for i in graph.subjects(RDF.type, bf.Instance) ])
# Out:
# 229

# %%
len([ cl for cl in graph.subjects(RDF.type, bf.Classification) ])
# Out:
# 10

# %%
agent_names = set()
for s in graph.subjects(RDF.type, bf.Instance):
    for agent in graph.objects(s, bf.contributor):
        name = graph.value(agent, RDFS.label)
        print(agent, name)
        agent_names.add(name)
# ub2bL6862C9 Oliver Harris
# ub2bL7704C20 William S. Burroughs
# ub2bL4486C20 William S. Burroughs
# ub2bL4859C20 William S. Burroughs
# ub2bL2253C20 William S. Burroughs
# ub2bL4097C9 William S. Burroughs
# ub2bL4101C9 Sinclair Beiles
# ub2bL4105C9 Brion Gysin
# ub2bL4093C20 Gregory Corso
# ub2bL7809C20 George Condo
# ub2bL7817C9 William S. Burroughs
# ub2bL7813C9 James Grauerholz
# ub2bL2850C20 William S. Burroughs
# ub2bL2229C20 William S. Burroughs
# ub2bL7615C9 William S. Burroughs
# ub2bL7619C9 Henri Chopin
# ub2bL7623C9 Brion Gysin
# ub2bL7611C20 Jean Chopin
# ub2bL4180C9 William S. Burroughs
# ub2bL4176C20 Carl Apfelschnitt
# ub2bL6026C9 William S. Burroughs
# ub2bL6022C9 Brion Gysin
# ub2bL6016C20 Oliver Harris
# ub2bL4891C20 William S. Burroughs
# ub2bL3554C9 William S. Burroughs
# ub2bL3550C20 Patrick Reagh

# %%
import spotlight

# %%
agent_name_dbpedia_uri_map = {}
for name in agent_names:
    try:
        candidates = spotlight.annotate('http://model.dbpedia-spotlight.org/en/annotate', 
                                           name.toPython(), 
                                           confidence=0.3, 
                                           support=2)
        agent_name_dbpedia_uri_map[name.toPython()] = candidates[0]['URI']
    except spotlight.SpotlightException:
        print(f"No DBPedia URI found for {name}")
# Out:
# No DBPedia URI found for Francisco
# No DBPedia URI found for Jean HÃ©lion
# No DBPedia URI found for Arthur Richardson
# No DBPedia URI found for Carl Apfelschnitt
# No DBPedia URI found for Carl Weissner
# No DBPedia URI found for Philippe Mikriammos

# %%
agent_name_dbpedia_uri_map
# Out:
# {'Alan Ansen': 'http://dbpedia.org/resource/Alan_Ansen',
#  'Alex Wermer-Colan': 'http://dbpedia.org/resource/Alex_Russo',
#  'Alfred Aranowitz': 'http://dbpedia.org/resource/Alfred_the_Great',
#  'Allen Ginsberg': 'http://dbpedia.org/resource/Allen_Ginsberg',
#  'Ann Douglas': 'http://dbpedia.org/resource/Ann_Perkins',
#  'Barry Miles': 'http://dbpedia.org/resource/Barry_Miles',
#  'Bob Gale': 'http://dbpedia.org/resource/Bob_Gale',
#  'Bob Kaufman': 'http://dbpedia.org/resource/Bob_Kaufman',
#  'Brion Gysin': 'http://dbpedia.org/resource/Brion_Gysin',
#  'Burroughs': 'http://dbpedia.org/resource/William_S._Burroughs',
#  'Byron James Bignell': 'http://dbpedia.org/resource/Lord_Byron',
#  'Carl Solomon': 'http://dbpedia.org/resource/Carl_Solomon',
#  'Casa Sin Nombre': 'http://dbpedia.org/resource/Sin_Nombre_(2009_film)',
#  'Christine Taylor': 'http://dbpedia.org/resource/Christine_Taylor',
#  'Christof KohlhÃ¶fer': 'http://dbpedia.org/resource/Fer',
#  'Claude PÃ©lieu': 'http://dbpedia.org/resource/Claude_Brasseur',
#  'Dave L. Haselwood': 'http://dbpedia.org/resource/Carl_Linnaeus',
#  'David Hockney': 'http://dbpedia.org/resource/David_Hockney',
#  'David L. Ulin': 'http://dbpedia.org/resource/Carl_Linnaeus',
#  'E. S. Seldon': 'http://dbpedia.org/resource/Seldon_Connor',
#  'Eric Mottram': 'http://dbpedia.org/resource/Eric_Mottram',
#  'Francesco Clemente': 'http://dbpedia.org/resource/Francesco_Clemente',
#  'Geoffrey D. Smith': 'http://dbpedia.org/resource/Josh_Smith',
#  'George Condo': 'http://dbpedia.org/resource/George_Condo',
#  'Graham Dawes': 'http://dbpedia.org/resource/Benjamin_Graham',
#  'Gregory Corso': 'http://dbpedia.org/resource/Gregory_Corso',
#  'GÃ©rard-Georges Lemaire': 'http://dbpedia.org/resource/Charles_Antoine_Lemaire',
#  'Henri Chopin': 'http://dbpedia.org/resource/Henri_Chopin',
#  'Howard Buchwald': 'http://dbpedia.org/resource/Dwight_Howard',
#  'Ian Sommerville': 'http://dbpedia.org/resource/Ian_Sommerville_(technician)',
#  'Ira Silverberg': 'http://dbpedia.org/resource/Ira_Silverberg',
#  'J.G. Ballard': 'http://dbpedia.org/resource/M._Russell_Ballard',
#  'Jack Kerouac': 'http://dbpedia.org/resource/Jack_Kerouac',
#  'James F. McIlroy': 'http://dbpedia.org/resource/LeBron_James',
#  'James Grauerholz': 'http://dbpedia.org/resource/James_Grauerholz',
#  'James Kearns': 'http://dbpedia.org/resource/LeBron_James',
#  'James R. Silke': 'http://dbpedia.org/resource/LeBron_James',
#  'Jean Chopin': 'http://dbpedia.org/resource/Frédéric_Chopin',
#  'Jean-Jacques Lebel': 'http://dbpedia.org/resource/Jean-Jacques_Lebel',
#  'Jennie Skerl': 'http://dbpedia.org/resource/Lady_Randolph_Churchill',
#  'Jim Pennington': 'http://dbpedia.org/resource/Chad_Pennington',
#  'Jo Verbrugghen': 'http://dbpedia.org/resource/Jo_Grant',
#  'John Calder': 'http://dbpedia.org/resource/John_Calder',
#  'John Ciardi': 'http://dbpedia.org/resource/John_Ciardi',
#  'John M. Bennett': 'http://dbpedia.org/resource/John_Studebaker',
#  'John Walsh': 'http://dbpedia.org/resource/John_Walsh_(television_host)',
#  'Kathy Acker': 'http://dbpedia.org/resource/Kathy_Acker',
#  "Liam O'Gallagher": 'http://dbpedia.org/resource/Liam',
#  'Lucien Suel': 'http://dbpedia.org/resource/Suloise',
#  'March': 'http://dbpedia.org/resource/March',
#  'Mary Beach': 'http://dbpedia.org/resource/Mary_I_of_England',
#  'Michael Montfort': 'http://dbpedia.org/resource/Pierre_Denys_de_Montfort',
#  'Michael Portman': 'http://dbpedia.org/resource/Rachel_Portman',
#  'Michael Scott Cain': 'http://dbpedia.org/resource/Michael_Scott_(The_Office)',
#  'Norman Mailer': 'http://dbpedia.org/resource/Norman_Mailer',
#  'Oliver Harris': 'http://dbpedia.org/resource/Oliver_Harris',
#  'Patrick Reagh': 'http://dbpedia.org/resource/Saint_Patrick',
#  'Paul Bowles': 'http://dbpedia.org/resource/Paul_Bowles',
#  'Raymond Foye': 'http://dbpedia.org/resource/Raymond_Rougeau',
#  'Robert F. Gale': 'http://dbpedia.org/resource/Gale',
#  'Robert H. Jackson': 'http://dbpedia.org/resource/Hydrogen',
#  'Robert Lowell': 'http://dbpedia.org/resource/Robert_Lowell',
#  'Ross MacLean': 'http://dbpedia.org/resource/Ross_MacLean',
#  'S Clay Wilson': 'http://dbpedia.org/resource/Clay',
#  'S. Clay Wilson': 'http://dbpedia.org/resource/Clay',
#  'Santa Fe': 'http://dbpedia.org/resource/Santa_Fe_Province',
#  'Sinclair Beiles': 'http://dbpedia.org/resource/Sinclair_Beiles',
#  'Steve Miller': 'http://dbpedia.org/resource/Steve_Miller_Band',
#  'Terry Southern': 'http://dbpedia.org/resource/Terry_Southern',
#  'Will Self': 'http://dbpedia.org/resource/Will_Self',
#  'William S. Burroughs': 'http://dbpedia.org/resource/William_S._Burroughs'}

# %%
place_names = set()
publisher_names = set()
for s in graph.subjects(RDF.type, bf.Instance):
    for activity in graph.objects(s, bf.provisionActivity):
        name = graph.value(activity, bf.place)
        if name:
            print(place, name)
            place_names.add(name)
        name = graph.value(activity, bf.agent)
        if name:
            print(agent, name)
            publisher_names.add(name)
# Out:
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Penguin
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Press
# ub2bL3574C26 New York
# ub2bL3550C20 Ace Books
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 London
# ub2bL3550C20 New English Library
# ub2bL3574C26 London
# ub2bL3550C20 David Bruce & Watson
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 [London]
# ub2bL3550C20 Picador
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Small Press Distribution
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 London
# ub2bL3550C20 Pan/Picador
# ub2bL3574C26 New York
# ub2bL3550C20 Riverrun Press
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 New York
# ub2bL3550C20 Seaver Books
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Beach Books, Texts, & Documents
# ub2bL3574C26 New York
# ub2bL3550C20 H. Holt
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 Brighton, England
# ub2bL3550C20 Urgency Press Rip-Off
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 [n.p.]
# ub2bL3550C20 The Horse Press
# ub2bL3574C26 [New York]
# ub2bL3550C20 [The Center for the Humanities, The Graduate Center, The City University of New York]
# ub2bL3574C26 New York
# ub2bL3550C20 Viking/Penguin
# ub2bL3574C26 New York
# ub2bL3550C20 Whitney Museum of American Art
# ub2bL3574C26 Ollon, Switzerland
# ub2bL3550C20 Am Here Books
# ub2bL3574C26 London
# ub2bL3550C20 Covent Garden Press Limited
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Paris
# ub2bL3550C20 Ãditions de L'Herne
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 Santa Fe, N.M.
# ub2bL3550C20 Casa Sin Nombre
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 [Holland]
# ub2bL3550C20 Agathon
# ub2bL3574C26 London
# ub2bL3550C20 Calder and Boyars
# ub2bL3574C26 Caen, France
# ub2bL3550C20 Cahiers de Nuit
# ub2bL3574C26 London
# ub2bL3550C20 Paladin/Grafton Books
# ub2bL3574C26 New York
# ub2bL3550C20 Holt, Rinehart and Winston
# ub2bL3574C26 New York
# ub2bL3550C20 Red Ozier Press
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Press
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 Picador
# ub2bL3574C26 New York
# ub2bL3550C20 âCâ Press
# ub2bL3574C26 GÃ¶ttingen
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 Charleston, W.Va.
# ub2bL3550C20 Parchment Gallery Graphics, Department of Humanities, University of Charleston
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 Paris
# ub2bL3550C20 Olympia Press
# ub2bL3574C26 London
# ub2bL3550C20 Paladin
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press/Atlantic Monthly
# ub2bL3574C26 London
# ub2bL3550C20 J. Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Penguin
# ub2bL3574C26 [San Francisco]
# ub2bL3550C20 Beach Books, Texts, & Documents
# ub2bL3574C26 London
# ub2bL3550C20 Aloes Books
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Press
# ub2bL3574C26 Paris
# ub2bL3550C20 Ãditions de L'Herne
# ub2bL3574C26 London
# ub2bL3550C20 Corgi Books
# ub2bL3574C26 London
# ub2bL3550C20 Penguin-UK
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Beach Books, Texts, & Documents
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Paris
# ub2bL3550C20 Ãditions de L'Herne
# ub2bL3574C26 London
# ub2bL3550C20 Calder & Boyars
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 H. Holt
# ub2bL3574C26 Secaucus, N.J.
# ub2bL3550C20 Castle Books
# ub2bL3574C26 Paris
# ub2bL3550C20 Flammarion
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 [n.p.]
# ub2bL3550C20 [n.p.]
# ub2bL3574C26 [Bonn]
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 [St. Paul, Minn.]
# ub2bL3550C20 Bookslinger
# ub2bL3574C26 [New York]
# ub2bL3550C20 High Risk Books
# ub2bL3574C26 GÃ¶ttingen
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 Jonathan Cape
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Dave Haselwood Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 Berguette, France
# ub2bL3550C20 Station Underground dâEmerveillement LittÃ©raire
# ub2bL3574C26 Louisville, Ky.
# ub2bL3550C20 White Fields Press
# ub2bL3574C26 [n.p.]
# ub2bL3550C20 [n.p.]
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Viking/Penguin
# ub2bL3574C26 Forest Knolls, Calif.
# ub2bL3550C20 Skyline Books
# ub2bL3574C26 London
# ub2bL3550C20 Pan Books/Picador
# ub2bL3574C26 New York
# ub2bL3550C20 Seaver Books
# ub2bL3574C26 [Louisville, Ky.]
# ub2bL3550C20 White Fields Press
# ub2bL3574C26 London
# ub2bL3550C20 Tandem Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Blue Wind Press
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Blue Wind Press
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Weidenfeld
# ub2bL3574C26 Madras, India; New York
# ub2bL3550C20 Hanuman Books
# ub2bL3574C26 New York
# ub2bL3550C20 American Theatre for Poets
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 City Moon
# ub2bL3574C26 New York
# ub2bL3550C20 Holt, Rinehart, and Winston
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Weidenfeld
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Nova Broadcast Press
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin
# ub2bL3574C26 New York
# ub2bL3550C20 Holt, Rinehart, and Winston
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Blue Wind Press
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Odd-Job Press
# ub2bL3574C26 New York
# ub2bL3550C20 Quality Paperbook Book Club
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Penguin
# ub2bL3574C26 London
# ub2bL3550C20 Paperview/Harper Perennial
# ub2bL3574C26 New York
# ub2bL3550C20 Ballantine Books
# ub2bL3574C26 London
# ub2bL3550C20 Penguin
# ub2bL3574C26 Santa Barbara, Calif.
# ub2bL3550C20 Cadmus Editions
# ub2bL3574C26 [Paris]
# ub2bL3550C20 Ãditions de L'Herne
# ub2bL3574C26 London
# ub2bL3550C20 Calder and Boyars
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 [Geneva]
# ub2bL3550C20 [Editions Claude Givaudan]
# ub2bL3574C26 London
# ub2bL3550C20 Paladin Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Columbus, Ohio
# ub2bL3550C20 The Ohio State University Press
# ub2bL3574C26 London
# ub2bL3550C20 Calder
# ub2bL3574C26 Rouen, France
# ub2bL3550C20 DerriÃ¨re la Salle de Bains
# ub2bL3574C26 New York
# ub2bL3550C20 Grenfell Press
# ub2bL3574C26 New York
# ub2bL3550C20 Viking Press
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 Paris
# ub2bL3550C20 The Olympia Press
# ub2bL3574C26 Ingatestone, Essex, England
# ub2bL3550C20 OU-Editions
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 Cherry Valley, N.Y.
# ub2bL3550C20 Cherry Valley Editions
# ub2bL3574C26 London
# ub2bL3550C20 W. H. Allen
# ub2bL3574C26 [London]
# ub2bL3550C20 Corgi Books
# ub2bL3574C26 Ingatestone, Essex
# ub2bL3550C20 OU
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Northridge, [UK]
# ub2bL3550C20 Lord John Press
# ub2bL3574C26 [Paris]
# ub2bL3550C20 Two Cities Editions
# ub2bL3574C26 London
# ub2bL3550C20 Panther Books/Granada Publishing
# ub2bL3574C26 Santa Barbara, Calif.
# ub2bL3550C20 Bradford Morrow
# ub2bL3574C26 New York
# ub2bL3550C20 Picador USA
# ub2bL3574C26 Paris
# ub2bL3550C20 Christian Bourgois Editeur
# ub2bL3574C26 London
# ub2bL3550C20 Corgi Books
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 New York
# ub2bL3550C20 Serpentâs Tail/High Risk Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 Corgi Books
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 London
# ub2bL3550C20 Corgi Books
# ub2bL3574C26 New York
# ub2bL3550C20 Ballantine Books
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 London
# ub2bL3550C20 Calder and Boyars
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 Santa Barbara, Calif.
# ub2bL3550C20 Cadmus Editions
# ub2bL3574C26 Sussex, England
# ub2bL3550C20 Urgency Press Rip-Off
# ub2bL3574C26 London
# ub2bL3550C20 Cape Goliard Press
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 Penguin
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 London
# ub2bL3550C20 Picador
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 GÃ¶ttingen
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Seaver Books
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Blue Wind Press
# ub2bL3574C26 Cherry Valley, N.Y.
# ub2bL3550C20 Cherry Valley Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Pequod Press
# ub2bL3574C26 London
# ub2bL3550C20 Picador
# ub2bL3574C26 London
# ub2bL3550C20 Calder and Boyars
# ub2bL3574C26 New York
# ub2bL3550C20 The Center for the Humanities, The Graduate Center, The City University of New York
# ub2bL3574C26 New York
# ub2bL3550C20 Holt, Rinehart, and Winston
# ub2bL3574C26 [Flint, Michigan]
# ub2bL3550C20 Fenian Head Centre Press
# ub2bL3574C26 London
# ub2bL3550C20 Paladin/Grafton Books
# ub2bL3574C26 Birmingham, England
# ub2bL3550C20 TOPY Heart
# ub2bL3574C26 New York
# ub2bL3550C20 Arcade
# ub2bL3574C26 Brighton, England
# ub2bL3550C20 Unicorn Books
# ub2bL3574C26 New York
# ub2bL3550C20 Viking/Penguin
# ub2bL3574C26 New York
# ub2bL3550C20 Picador USA
# ub2bL3574C26 [San Francisco]
# ub2bL3550C20 Beach Books, Texts, & Documents
# ub2bL3574C26 London
# ub2bL3550C20 Serpentâs Tail
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 Berkeley, Calif.
# ub2bL3550C20 Blue Wind Press
# ub2bL3574C26 New York
# ub2bL3550C20 Hand-Job Press
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 [Bonn]
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Tangier
# ub2bL3550C20 Ira Cohen
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Auerhahn Press
# ub2bL3574C26 Bonn
# ub2bL3550C20 Expanded Media Editions
# ub2bL3574C26 New York
# ub2bL3550C20 Fuck You Press
# ub2bL3574C26 New York
# ub2bL3550C20 H. Holt
# ub2bL3574C26 New York
# ub2bL3550C20 Arcade
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 London
# ub2bL3550C20 [n.p.]
# ub2bL3574C26 Sudbury, Mass.
# ub2bL3550C20 Water Row Books
# ub2bL3574C26 [Lawrence, Kansas?]
# ub2bL3550C20 Kavyayantra Press
# ub2bL3574C26 London
# ub2bL3550C20 Digit Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Fuck You Press
# ub2bL3574C26 New York
# ub2bL3550C20 [n.p.]
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Penguin Books
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 [Encinitas, Calif.]
# ub2bL3550C20 FreeThought Publications
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Ace Books
# ub2bL3574C26 London
# ub2bL3550C20 Pan/Picador
# ub2bL3574C26 San Francisco
# ub2bL3550C20 City Lights Books
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 London
# ub2bL3550C20 Flamingo
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Paris
# ub2bL3550C20 Olympia Press
# ub2bL3574C26 San Francisco
# ub2bL3550C20 Beach Books, Texts, & Documents
# ub2bL3574C26 New York
# ub2bL3550C20 Library Fellows of the Whitney Museum of American Art
# ub2bL3574C26 London
# ub2bL3550C20 Aloes seolA [i.e., Aloes Books]
# ub2bL3574C26 London
# ub2bL3550C20 John Calder
# ub2bL3574C26 Cambridge
# ub2bL3550C20 Blackmoor Head Press
# ub2bL3574C26 DÃ¼sseldorf; New York
# ub2bL3550C20 Edition Gunnar A. Kaldewey
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 New York
# ub2bL3550C20 Grove Press
# ub2bL3574C26 Santa Barbara, Calif.
# ub2bL3550C20 Bradford Morrow

# %%
place_names
# Out:
# {rdflib.term.Literal('Berguette, France'),
#  rdflib.term.Literal('Berkeley, Calif.'),
#  rdflib.term.Literal('Birmingham, England'),
#  rdflib.term.Literal('Bonn'),
#  rdflib.term.Literal('Brighton, England'),
#  rdflib.term.Literal('Caen, France'),
#  rdflib.term.Literal('Cambridge'),
#  rdflib.term.Literal('Charleston, W.Va.'),
#  rdflib.term.Literal('Cherry Valley, N.Y.'),
#  rdflib.term.Literal('Columbus, Ohio'),
#  rdflib.term.Literal('DÃ¼sseldorf; New York'),
#  rdflib.term.Literal('Forest Knolls, Calif.'),
#  rdflib.term.Literal('GÃ¶ttingen'),
#  rdflib.term.Literal('Ingatestone, Essex'),
#  rdflib.term.Literal('Ingatestone, Essex, England'),
#  rdflib.term.Literal('London'),
#  rdflib.term.Literal('Louisville, Ky.'),
#  rdflib.term.Literal('Madras, India; New York'),
#  rdflib.term.Literal('New York'),
#  rdflib.term.Literal('Northridge, [UK]'),
#  rdflib.term.Literal('Ollon, Switzerland'),
#  rdflib.term.Literal('Paris'),
#  rdflib.term.Literal('Rouen, France'),
#  rdflib.term.Literal('San Francisco'),
#  rdflib.term.Literal('Santa Barbara, Calif.'),
#  rdflib.term.Literal('Santa Fe, N.M.'),
#  rdflib.term.Literal('Secaucus, N.J.'),
#  rdflib.term.Literal('Sudbury, Mass.'),
#  rdflib.term.Literal('Sussex, England'),
#  rdflib.term.Literal('Tangier'),
#  rdflib.term.Literal('[Bonn]'),
#  rdflib.term.Literal('[Encinitas, Calif.]'),
#  rdflib.term.Literal('[Flint, Michigan]'),
#  rdflib.term.Literal('[Geneva]'),
#  rdflib.term.Literal('[Holland]'),
#  rdflib.term.Literal('[Lawrence, Kansas?]'),
#  rdflib.term.Literal('[London]'),
#  rdflib.term.Literal('[Louisville, Ky.]'),
#  rdflib.term.Literal('[New York]'),
#  rdflib.term.Literal('[Paris]'),
#  rdflib.term.Literal('[San Francisco]'),
#  rdflib.term.Literal('[St. Paul, Minn.]'),
#  rdflib.term.Literal('[n.p.]')}

# %%
place_name_dbpedia_uri_map = {}
for name in place_names:
    try:
        candidates = spotlight.annotate('http://model.dbpedia-spotlight.org/en/annotate', 
                                           name.toPython(), 
                                           confidence=0.3, 
                                           support=2)
        place_name_dbpedia_uri_map[name.toPython()] = candidates[0]['URI']
    except spotlight.SpotlightException:
        print(f"No DBPedia URI found for {name}")
# Out:
# No DBPedia URI found for [n.p.]
# No DBPedia URI found for GÃ¶ttingen

# %%
place_name_dbpedia_uri_map
# Out:
# {'Berguette, France': 'http://dbpedia.org/resource/France',
#  'Berkeley, Calif.': 'http://dbpedia.org/resource/Berkeley,_California',
#  'Birmingham, England': 'http://dbpedia.org/resource/Birmingham',
#  'Bonn': 'http://dbpedia.org/resource/Bonn',
#  'Brighton, England': 'http://dbpedia.org/resource/Brighton',
#  'Caen, France': 'http://dbpedia.org/resource/Caen',
#  'Cambridge': 'http://dbpedia.org/resource/Cambridge',
#  'Charleston, W.Va.': 'http://dbpedia.org/resource/Charleston,_South_Carolina',
#  'Cherry Valley, N.Y.': 'http://dbpedia.org/resource/Cherry_Valley_massacre',
#  'Columbus, Ohio': 'http://dbpedia.org/resource/Ohio',
#  'DÃ¼sseldorf; New York': 'http://dbpedia.org/resource/New_York',
#  'Forest Knolls, Calif.': 'http://dbpedia.org/resource/List_of_neighborhoods_in_San_Francisco',
#  'Ingatestone, Essex': 'http://dbpedia.org/resource/Ingatestone',
#  'Ingatestone, Essex, England': 'http://dbpedia.org/resource/Ingatestone',
#  'London': 'http://dbpedia.org/resource/London',
#  'Louisville, Ky.': 'http://dbpedia.org/resource/University_of_Louisville',
#  'Madras, India; New York': 'http://dbpedia.org/resource/Chennai',
#  'New York': 'http://dbpedia.org/resource/New_York',
#  'Northridge, [UK]': 'http://dbpedia.org/resource/1994_Northridge_earthquake',
#  'Ollon, Switzerland': 'http://dbpedia.org/resource/Ollon',
#  'Paris': 'http://dbpedia.org/resource/Paris',
#  'Rouen, France': 'http://dbpedia.org/resource/Rouen',
#  'San Francisco': 'http://dbpedia.org/resource/San_Francisco',
#  'Santa Barbara, Calif.': 'http://dbpedia.org/resource/Santa_Barbara_Unified_School_District',
#  'Santa Fe, N.M.': 'http://dbpedia.org/resource/Santa_Fe_Province',
#  'Secaucus, N.J.': 'http://dbpedia.org/resource/Secaucus_Junction',
#  'Sudbury, Mass.': 'http://dbpedia.org/resource/Greater_Sudbury',
#  'Sussex, England': 'http://dbpedia.org/resource/Sussex',
#  'Tangier': 'http://dbpedia.org/resource/Tangier',
#  '[Bonn]': 'http://dbpedia.org/resource/Bonn',
#  '[Encinitas, Calif.]': 'http://dbpedia.org/resource/Encinitas,_California',
#  '[Flint, Michigan]': 'http://dbpedia.org/resource/Michigan',
#  '[Geneva]': 'http://dbpedia.org/resource/Geneva',
#  '[Holland]': 'http://dbpedia.org/resource/Holland',
#  '[Lawrence, Kansas?]': 'http://dbpedia.org/resource/Kansas',
#  '[London]': 'http://dbpedia.org/resource/London',
#  '[Louisville, Ky.]': 'http://dbpedia.org/resource/University_of_Louisville',
#  '[New York]': 'http://dbpedia.org/resource/New_York',
#  '[Paris]': 'http://dbpedia.org/resource/Paris',
#  '[San Francisco]': 'http://dbpedia.org/resource/San_Francisco',
#  '[St. Paul, Minn.]': 'http://dbpedia.org/resource/Saint'}

# %%
publisher_name_dbpedia_uri_map = {}
for name in publisher_names:
    try:
        candidates = spotlight.annotate('http://model.dbpedia-spotlight.org/en/annotate', 
                                           name.toPython(), 
                                           confidence=0.3, 
                                           support=2)
        publisher_name_dbpedia_uri_map[name.toPython()] = candidates[0]['URI']
    except spotlight.SpotlightException:
        print(f"No DBPedia URI found for {name}")
# Out:
# No DBPedia URI found for Odd-Job Press
# No DBPedia URI found for [n.p.]
# No DBPedia URI found for Penguin
# No DBPedia URI found for Hand-Job Press
# No DBPedia URI found for OU
# No DBPedia URI found for Penguin-UK
# No DBPedia URI found for OU-Editions
# No DBPedia URI found for Flamingo
# No DBPedia URI found for Bookslinger
# No DBPedia URI found for Cahiers de Nuit

# %%
publisher_name_dbpedia_uri_map
# Out:
# {'Ace Books': 'http://dbpedia.org/resource/Ace_Books',
#  'Agathon': 'http://dbpedia.org/resource/Agathon',
#  'Aloes Books': 'http://dbpedia.org/resource/Agarwood',
#  'Aloes seolA [i.e., Aloes Books]': 'http://dbpedia.org/resource/Agarwood',
#  'Am Here Books': 'http://dbpedia.org/resource/United_States',
#  'American Theatre for Poets': 'http://dbpedia.org/resource/Theatre',
#  'Arcade': 'http://dbpedia.org/resource/Arcade_game',
#  'Auerhahn Press': 'http://dbpedia.org/resource/Auerhahn_Press',
#  'Ballantine Books': 'http://dbpedia.org/resource/Ballantine_Books',
#  'Beach Books, Texts, & Documents': 'http://dbpedia.org/resource/Beach',
#  'Blackmoor Head Press': 'http://dbpedia.org/resource/Flanaess',
#  'Blue Wind Press': 'http://dbpedia.org/resource/Blue_Wind',
#  'Bradford Morrow': 'http://dbpedia.org/resource/Bradford_Morrow',
#  'Cadmus Editions': 'http://dbpedia.org/resource/Cadmus',
#  'Calder': 'http://dbpedia.org/resource/Alexander_Calder',
#  'Calder & Boyars': 'http://dbpedia.org/resource/Alexander_Calder',
#  'Calder and Boyars': 'http://dbpedia.org/resource/Alexander_Calder',
#  'Cape Goliard Press': 'http://dbpedia.org/resource/Goliard',
#  'Casa Sin Nombre': 'http://dbpedia.org/resource/Sin_Nombre_(2009_film)',
#  'Castle Books': 'http://dbpedia.org/resource/Castle',
#  'Cherry Valley Editions': 'http://dbpedia.org/resource/Cherry_Valley_massacre',
#  'Christian Bourgois Editeur': 'http://dbpedia.org/resource/Christian',
#  'City Lights Books': 'http://dbpedia.org/resource/City_Lights_Bookstore',
#  'City Moon': 'http://dbpedia.org/resource/City',
#  'Corgi Books': 'http://dbpedia.org/resource/Transworld_Publishers',
#  'Covent Garden Press Limited': 'http://dbpedia.org/resource/Covent_Garden',
#  'Dave Haselwood Books': 'http://dbpedia.org/resource/Book',
#  'David Bruce & Watson': 'http://dbpedia.org/resource/David_II_of_Scotland',
#  'DerriÃ¨re la Salle de Bains': 'http://dbpedia.org/resource/La_Salle_University',
#  'Digit Books': 'http://dbpedia.org/resource/Numerical_digit',
#  'Edition Gunnar A. Kaldewey': 'http://dbpedia.org/resource/Special_edition',
#  'Expanded Media Editions': 'http://dbpedia.org/resource/Valery_Leontiev_discography',
#  'Fenian Head Centre Press': 'http://dbpedia.org/resource/Fenian',
#  'Flammarion': 'http://dbpedia.org/resource/Groupe_Flammarion',
#  'FreeThought Publications': 'http://dbpedia.org/resource/Publication',
#  'Fuck You Press': 'http://dbpedia.org/resource/Fuck_You_(CeeLo_Green_song)',
#  'Grenfell Press': 'http://dbpedia.org/resource/Bernard_Pyne_Grenfell',
#  'Grove Press': 'http://dbpedia.org/resource/Grove_Press',
#  'Grove Press/Atlantic Monthly': 'http://dbpedia.org/resource/Grove_Press',
#  'Grove Weidenfeld': 'http://dbpedia.org/resource/Grove_Press',
#  'Grove Weidenfeld ': 'http://dbpedia.org/resource/Grove_Press',
#  'H. Holt': 'http://dbpedia.org/resource/Hydrogen',
#  'Hanuman Books': 'http://dbpedia.org/resource/Hanuman_Books',
#  'High Risk Books': 'http://dbpedia.org/resource/High_Risk_Books',
#  'Holt, Rinehart and Winston': 'http://dbpedia.org/resource/Henry_Holt_and_Company',
#  'Holt, Rinehart, and Winston': 'http://dbpedia.org/resource/Henry_Holt_and_Company',
#  'Ira Cohen': 'http://dbpedia.org/resource/Ira_Cohen',
#  'J. Calder': 'http://dbpedia.org/resource/Judge',
#  'John Calder': 'http://dbpedia.org/resource/John_Calder',
#  'Jonathan Cape': 'http://dbpedia.org/resource/Jonathan_Cape',
#  'Kavyayantra Press': 'http://dbpedia.org/resource/News_media',
#  'Library Fellows of the Whitney Museum of American Art': 'http://dbpedia.org/resource/Library',
#  'Lord John Press': 'http://dbpedia.org/resource/Lord_John',
#  'New English Library': 'http://dbpedia.org/resource/New_English_Library',
#  'Nova Broadcast Press': 'http://dbpedia.org/resource/News_media',
#  'Olympia Press': 'http://dbpedia.org/resource/Olympia_Press',
#  'Paladin': 'http://dbpedia.org/resource/Paladin',
#  'Paladin Books': 'http://dbpedia.org/resource/Paladin',
#  'Paladin/Grafton Books': 'http://dbpedia.org/resource/Paladin',
#  'Pan Books/Picador': 'http://dbpedia.org/resource/Pan_Books',
#  'Pan/Picador': 'http://dbpedia.org/resource/Picador',
#  'Panther Books/Granada Publishing': 'http://dbpedia.org/resource/Panther_Books',
#  'Paperview/Harper Perennial': 'http://dbpedia.org/resource/HarperCollins',
#  'Parchment Gallery Graphics, Department of Humanities, University of Charleston': 'http://dbpedia.org/resource/Parchment',
#  'Penguin Books': 'http://dbpedia.org/resource/Penguin_Books',
#  'Pequod Press': 'http://dbpedia.org/resource/Pequod_(Moby-Dick)',
#  'Picador': 'http://dbpedia.org/resource/Picador',
#  'Picador USA': 'http://dbpedia.org/resource/Picador',
#  'Quality Paperbook Book Club': 'http://dbpedia.org/resource/Book_sales_club',
#  'Red Ozier Press': 'http://dbpedia.org/resource/Red',
#  'Riverrun Press': 'http://dbpedia.org/resource/World_of_A_Song_of_Ice_and_Fire',
#  'Seaver Books': 'http://dbpedia.org/resource/Book',
#  'Serpentâ\x80\x99s Tail': 'http://dbpedia.org/resource/Tail',
#  'Serpentâ\x80\x99s Tail/High Risk Books': 'http://dbpedia.org/resource/Tail',
#  'Skyline Books': 'http://dbpedia.org/resource/Nissan_Skyline',
#  'Small Press Distribution': 'http://dbpedia.org/resource/Small_Press_Distribution',
#  'Station Underground dâ\x80\x99Emerveillement LittÃ©raire': 'http://dbpedia.org/resource/Train_station',
#  'TOPY Heart': 'http://dbpedia.org/resource/Thee_Temple_ov_Psychick_Youth',
#  'Tandem Books': 'http://dbpedia.org/resource/Universal-Tandem_Publishing',
#  'The Center for the Humanities, The Graduate Center, The City University of New York': 'http://dbpedia.org/resource/The_Center',
#  'The Horse Press': 'http://dbpedia.org/resource/The_Horse',
#  'The Ohio State University Press': 'http://dbpedia.org/resource/Ohio_State_University_Press',
#  'The Olympia Press': 'http://dbpedia.org/resource/Olympia_Press',
#  'Two Cities Editions': 'http://dbpedia.org/resource/City',
#  'Unicorn Books': 'http://dbpedia.org/resource/Unicorn',
#  'Urgency Press Rip-Off': 'http://dbpedia.org/resource/Urinary_urgency',
#  'Viking Penguin': 'http://dbpedia.org/resource/Viking_Press',
#  'Viking Press': 'http://dbpedia.org/resource/Viking_Press',
#  'Viking/Penguin': 'http://dbpedia.org/resource/Viking_Press',
#  'W. H. Allen': 'http://dbpedia.org/resource/Hydrogen',
#  'Water Row Books': 'http://dbpedia.org/resource/Water',
#  'White Fields Press': 'http://dbpedia.org/resource/White_Fields',
#  'Whitney Museum of American Art': 'http://dbpedia.org/resource/Whitney_Museum_of_American_Art',
#  '[Editions Claude Givaudan]': 'http://dbpedia.org/resource/Valery_Leontiev_discography',
#  '[The Center for the Humanities, The Graduate Center, The City University of New York]': 'http://dbpedia.org/resource/The_Center',
#  "Ã\x89ditions de L'Herne": "http://dbpedia.org/resource/L'Herne",
#  'â\x80\x9cCâ\x80\x9d Press': 'http://dbpedia.org/resource/News_media'}
